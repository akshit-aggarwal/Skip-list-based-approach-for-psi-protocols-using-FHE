# %%
#Random number generation
import random
import csv
import time

# Function to generate distinct random numbers within a range
def generate_random_numbers(count, range_min, range_max, exclude_set=None):
    if exclude_set is None:
        exclude_set = set()

    numbers = set()
    while len(numbers) < count:
        num = random.randint(range_min, range_max)
        if num not in exclude_set and num not in numbers:
            numbers.add(num)
    return list(numbers)

# Start time measurement
start_time = time.time()

# File names
server_file = "Server.csv"
client_file = "Client.csv"

# Parameters
server_count = 1000
client_count = 100
range_min, range_max = 1, 5000

# Generate random numbers for Server.csv
server_numbers = generate_random_numbers(server_count, range_min, range_max)

# Select some common numbers between server and client
common_count = random.randint(10, min(server_count, client_count) // 2)  # Random number of common elements
common_numbers = random.sample(server_numbers, common_count)

# Generate remaining client numbers ensuring no overlap except for common_numbers
remaining_client_numbers = generate_random_numbers(client_count - len(common_numbers), range_min, range_max, exclude_set=set(server_numbers))
client_numbers = common_numbers + remaining_client_numbers

# Shuffle client numbers to ensure randomness
random.shuffle(client_numbers)

# Write Server.csv
with open(server_file, "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Random Numbers"])
    writer.writerows([[num] for num in server_numbers])

# Write Client.csv
with open(client_file, "w", newline="") as file:
    writer = csv.writer(file)
    writer.writerow(["Random Numbers"])
    writer.writerows([[num] for num in client_numbers])

# End time measurement
end_time = time.time()
execution_time = end_time - start_time

print(f"Generated {server_file} and {client_file} in {execution_time:.2f} seconds.")
# Out:
# Generated Server.csv and Client.csv in 0.00 seconds.

# %%
import random
import csv
import time

# Function to generate distinct random numbers within a range
def generate_random_numbers(count, range_min, range_max, exclude_set=None):
    if exclude_set is None:
        exclude_set = set()

    numbers = set()
    while len(numbers) < count:
        num = random.randint(range_min, range_max)
        if num not in exclude_set and num not in numbers:
            numbers.add(num)
    return list(numbers)

# Skip list node class
class SkipListNode:
    def __init__(self, value, level):
        self.value = value
        self.forward = [None] * (level + 1)

# Skip list class
class SkipList:
    def __init__(self, max_level, p):
        self.max_level = max_level
        self.p = p
        self.header = self._create_node(-1, max_level)
        self.level = 0

    def _create_node(self, value, level):
        return SkipListNode(value, level)

    def random_level(self):
        level = 0
        while random.random() < self.p and level < self.max_level:
            level += 1
        return level

    def insert(self, value):
        update = [None] * (self.max_level + 1)
        current = self.header

        for i in range(self.level, -1, -1):
            while current.forward[i] and current.forward[i].value < value:
                current = current.forward[i]
            update[i] = current

        level = self.random_level()
        if level > self.level:
            for i in range(self.level + 1, level + 1):
                update[i] = self.header
            self.level = level

        new_node = self._create_node(value, level)
        for i in range(level + 1):
            new_node.forward[i] = update[i].forward[i]
            update[i].forward[i] = new_node

    def display(self):
        for i in range(self.level + 1):
            current = self.header.forward[i]
            print(f"Level {i}: ", end="")
            while current:
                print(current.value, end=" ")
                current = current.forward[i]
            print()

# Start time measurement for skip list creation
start_time = time.time()

# File name
server_file = "Server.csv"

# Read numbers from Server.csv
server_numbers = []
with open(server_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
# Level 3: 111 128 221 286 290 310 344 370 373 403 404 458 469 491 495 537 587 601 609 735 786 797 803 838 887 957 975 987 1009 1026 1055 1091 1099 1100 1136 1141 1144 1194 1287 1367 1372 1418 1427 1458 1463 1489 1503 1525 1568 1740 1748 1777 1800 1813 1828 1857 1917 1933 1937 1948 1972 1981 2116 2134 2137 2152 2192 2202 2252 2259 2438 2493 2507 2513 2526 2603 2610 2770 2841 2961 2994 3005 3024 3075 3113 3146 3149 3188 3190 3242 3250 3364 3371 3433 3442 3477 3580 3661 3702 3736 3779 3812 3864 3873 3885 3914 3954 3961 3998 4043 4110 4114 4165 4194 4228 4241 4297 4350 4427 4463 4497 4523 4562 4605 4655 4759 4763 4782 4784 4794 4807 4837 4844 4871 4879 4908 4935 4949
# Level 4: 128 286 310 370 373 403 404 469 491 495 537 587 609 797 975 1009 1026 1099 1100 1141 1367 1372 1418 1427 1458 1525 1740 1777 1933 1972 2192 2202 2252 2438 2493 2507 2526 2603 2994 3113 3149 3242 3371 3442 3477 3661 3779 3812 3864 3873 3885 3954 3961 4110 4241 4497 4523 4562 4655 4759 4763 4794 4807 4844 4871 4935
# Level 5: 128 310 370 403 404 469 491 587 797 1009 1100 1367 1458 1525 1777 2192 2252 2438 2507 2994 3113 3149 3242 3371 3477 3954 3961 4110 4497 4523 4562 4655 4759 4763 4807 4844 4871
# Level 6: 128 310 370 403 404 491 1100 1458 1777 2192 2252 2438 3113 3149 3242 3477 3954 4497 4523 4562 4655 4763
# Level 7: 128 370 403 491 2192 2252 2438 3113 3149 3242 3477 3954 4497 4523 4562 4763
# Level 8: 370 403 2192 2438 3113 3149 3242 3954 4763
# Level 9: 3149 3242 4763
# Level 10: 3242 4763
# Level 11: 3242 4763

# %%
import random
import csv
import time

# Function to generate distinct random numbers within a range
def generate_random_numbers(count, range_min, range_max, exclude_set=None):
    if exclude_set is None:
        exclude_set = set()

    numbers = set()
    while len(numbers) < count:
        num = random.randint(range_min, range_max)
        if num not in exclude_set and num not in numbers:
            numbers.add(num)
    return list(numbers)

# Skip list node class
class SkipListNode:
    def __init__(self, value, level):
        self.value = value
        self.forward = [None] * (level + 1)

# Skip list class
class SkipList:
    def __init__(self, max_level, p):
        self.max_level = max_level
        self.p = p
        self.header = self._create_node(-1, max_level)
        self.level = 0

    def _create_node(self, value, level):
        return SkipListNode(value, level)

    def random_level(self):
        level = 0
        while random.random() < self.p and level < self.max_level:
            level += 1
        return level

    def insert(self, value):
        update = [None] * (self.max_level + 1)
        current = self.header

        for i in range(self.level, -1, -1):
            while current.forward[i] and current.forward[i].value < value:
                current = current.forward[i]
            update[i] = current

        level = self.random_level()
        if level > self.level:
            for i in range(self.level + 1, level + 1):
                update[i] = self.header
            self.level = level

        new_node = self._create_node(value, level)
        for i in range(level + 1):
            new_node.forward[i] = update[i].forward[i]
            update[i].forward[i] = new_node

    def search(self, value):
        current = self.header
        comparisons = 0
        for i in range(self.level, -1, -1):
            while current.forward[i] and current.forward[i].value < value:
                current = current.forward[i]
                comparisons += 1
            comparisons += 1  # Compare with current.forward[i]

        current = current.forward[0]
        if current and current.value == value:
            comparisons += 1
            return True, comparisons

        return False, comparisons

# File names
server_file = "Server.csv"
client_file = "Client.csv"

# Read numbers from Server.csv
server_numbers = []
with open(server_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    server_numbers = [int(row[0]) for row in reader]

# Read numbers from Client.csv
client_numbers = []
with open(client_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    client_numbers = [int(row[0]) for row in reader]

# Create a skip list from server_numbers
max_level = 16
p = 0.5
skip_list = SkipList(max_level, p)
for number in server_numbers:
    skip_list.insert(number)

# Randomly pick one element from Client.csv
random_element = random.choice(client_numbers)
print(f"Randomly picked element from Client.csv: {random_element}")

# Search the element in the skip list
found, comparisons = skip_list.search(random_element)
if found:
    print(f"Element {random_element} is present in Server.csv (Skip List).")
else:
    print(f"Element {random_element} is NOT present in Server.csv (Skip List).")

print(f"Total number of comparisons: {comparisons}")
# Out:
# Randomly picked element from Client.csv: 982
# Element 982 is present in Server.csv (Skip List).
# Total number of comparisons: 16

# %%
pip install tenseal
# Out:
# Requirement already satisfied: tenseal in /home/rs/akshit.aggarwal/anaconda3/envs/myenv/lib/python3.9/site-packages (0.3.15)
# Note: you may need to restart the kernel to use updated packages.

# %%
#Encryption and Decryption

import tenseal as ts
import random
import csv
import time

# Skip list node class
class SkipListNode:
    def __init__(self, value, level):
        self.value = value
        self.forward = [None] * (level + 1)

# Skip list class
class SkipList:
    def __init__(self, max_level, p):
        self.max_level = max_level
        self.p = p
        self.header = self._create_node(-1, max_level)
        self.level = 0

    def _create_node(self, value, level):
        return SkipListNode(value, level)

    def random_level(self):
        level = 0
        while random.random() < self.p and level < self.max_level:
            level += 1
        return level

    def insert(self, value):
        update = [None] * (self.max_level + 1)
        current = self.header

        for i in range(self.level, -1, -1):
            while current.forward[i] and current.forward[i].value < value:
                current = current.forward[i]
            update[i] = current

        level = self.random_level()
        if level > self.level:
            for i in range(self.level + 1, level + 1):
                update[i] = self.header
            self.level = level

        new_node = self._create_node(value, level)
        for i in range(level + 1):
            new_node.forward[i] = update[i].forward[i]
            update[i].forward[i] = new_node

    def get_elements(self):
        current = self.header.forward[0]
        elements = []
        while current:
            elements.append(current.value)
            current = current.forward[0]
        return elements

# Load skip list elements directly from Server.csv
server_file = "Server.csv"
server_numbers = []
with open(server_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    server_numbers = [int(row[0]) for row in reader]

# Since the file already represents a skip list, we consider server_numbers as the skip list elements.
print("Server skip list loaded with 1000 elements from Server.csv.")

# Set up BFV Homomorphic Encryption Context
def setup_bfv_context():
    context = ts.context(ts.SCHEME_TYPE.BFV, poly_modulus_degree=8192, plain_modulus=1032193)
    return context

# Encrypt value in BFV

def encrypt_value(context, value):
    return ts.bfv_vector(context, [value])

# Homomorphic Comparison
def server_compare(enc_target, skip_list_value, r, context):
    enc_r = ts.bfv_vector(context, [r])
    enc_value = ts.bfv_vector(context, [skip_list_value])
    result = enc_target - enc_value
    result = result * enc_r  # Multiply by r
    return result

# Search Functionality
def encrypted_search(server_numbers, client_value, context):
    print("\nStarting Homomorphic Search...")
    target_enc = encrypt_value(context, client_value)
    comparisons = 0
    visited = set()

    # Simulate skip list traversal
    for i, value in enumerate(server_numbers):
        if value in visited:  # Skip already visited nodes
            continue
        visited.add(value)

        r = random.randint(1, 100)  # Random r > 0
        encrypted_result = server_compare(target_enc, value, r, context)

        # Simulate sending encrypted result back to client
        decrypted_result = encrypted_result.decrypt()[0] // r
        print(f"Node {value}, Decrypted Result: {decrypted_result}")

        comparisons += 1
        if decrypted_result == 0:
            print(f"\nNumber {client_value} found at iteration {comparisons}.")
            return True, comparisons

        if decrypted_result < 0:  # Move left (simulate)
            break

    print(f"\nNumber {client_value} NOT found after {comparisons} comparisons.")
    return False, comparisons

# Client Logic
client_file = "Client.csv"
client_numbers = []
with open(client_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    client_numbers = [int(row[0]) for row in reader]

random_client_value = random.choice(client_numbers)
print(f"Client randomly selected number: {random_client_value}")

# Setup BFV Context
bfv_context = setup_bfv_context()

# Perform Encrypted Search
start_time = time.time()
found, total_comparisons = encrypted_search(server_numbers, random_client_value, bfv_context)
end_time = time.time()

# Display Results
if found:
    print(f"\nNumber {random_client_value} was successfully found!")
else:
    print(f"\nNumber {random_client_value} was not found in the skip list.")

print(f"Total Comparisons: {total_comparisons}")
print(f"Execution Time: {end_time - start_time:.4f} seconds")
# Out:
# Server skip list loaded with 1000 elements from Server.csv.
# Client randomly selected number: 4872
#
# Starting Homomorphic Search...
# Node 1, Decrypted Result: 4871
# Node 2053, Decrypted Result: 2819
# Node 2054, Decrypted Result: 2818
# Node 2058, Decrypted Result: 2814
# Node 4107, Decrypted Result: 765
# Node 11, Decrypted Result: 4861
# Node 2061, Decrypted Result: 2811
# Node 4109, Decrypted Result: 763
# Node 2067, Decrypted Result: 2805
# Node 20, Decrypted Result: 4852
# Node 2069, Decrypted Result: 2803
# Node 4118, Decrypted Result: 754
# Node 2071, Decrypted Result: 2801
# Node 22, Decrypted Result: 4850
# Node 4119, Decrypted Result: 753
# Node 4121, Decrypted Result: 751
# Node 2075, Decrypted Result: 2797
# Node 28, Decrypted Result: 4844
# Node 29, Decrypted Result: 4843
# Node 4123, Decrypted Result: 749
# Node 4127, Decrypted Result: 745
# Node 2080, Decrypted Result: 2792
# Node 2072, Decrypted Result: 2800
# Node 2087, Decrypted Result: 2785
# Node 4137, Decrypted Result: 735
# Node 41, Decrypted Result: 4831
# Node 4139, Decrypted Result: 733
# Node 44, Decrypted Result: 4828
# Node 4141, Decrypted Result: 731
# Node 2094, Decrypted Result: 2778
# Node 47, Decrypted Result: 4825
# Node 4143, Decrypted Result: 729
# Node 2096, Decrypted Result: 2776
# Node 4140, Decrypted Result: 732
# Node 51, Decrypted Result: 4821
# Node 2100, Decrypted Result: 2772
# Node 4149, Decrypted Result: 723
# Node 54, Decrypted Result: 4818
# Node 2103, Decrypted Result: 2769
# Node 53, Decrypted Result: 4819
# Node 2105, Decrypted Result: 2767
# Node 58, Decrypted Result: 4814
# Node 2047, Decrypted Result: 2825
# Node 59, Decrypted Result: 4813
# Node 4151, Decrypted Result: 721
# Node 647, Decrypted Result: 4225
# Node 2701, Decrypted Result: 2171
# Node 4750, Decrypted Result: 122
# Node 4749, Decrypted Result: 123
# Node 4752, Decrypted Result: 120
# Node 2707, Decrypted Result: 2165
# Node 4756, Decrypted Result: 116
# Node 661, Decrypted Result: 4211
# Node 660, Decrypted Result: 4212
# Node 4759, Decrypted Result: 113
# Node 2713, Decrypted Result: 2159
# Node 666, Decrypted Result: 4206
# Node 2715, Decrypted Result: 2157
# Node 669, Decrypted Result: 4203
# Node 670, Decrypted Result: 4202
# Node 673, Decrypted Result: 4199
# Node 674, Decrypted Result: 4198
# Node 2724, Decrypted Result: 2148
# Node 2725, Decrypted Result: 2147
# Node 4773, Decrypted Result: 99
# Node 683, Decrypted Result: 4189
# Node 686, Decrypted Result: 4186
# Node 4784, Decrypted Result: 88
# Node 2736, Decrypted Result: 2136
# Node 2737, Decrypted Result: 2135
# Node 2739, Decrypted Result: 2133
# Node 693, Decrypted Result: 4179
# Node 2741, Decrypted Result: 2131
# Node 2743, Decrypted Result: 2129
# Node 4792, Decrypted Result: 80
# Node 4791, Decrypted Result: 81
# Node 2746, Decrypted Result: 2126
# Node 4795, Decrypted Result: 77
# Node 2748, Decrypted Result: 2124
# Node 4797, Decrypted Result: 75
# Node 4794, Decrypted Result: 78
# Node 4798, Decrypted Result: 74
# Node 697, Decrypted Result: 4175
# Node 4802, Decrypted Result: 70
# Node 2759, Decrypted Result: 2113
# Node 2760, Decrypted Result: 2112
# Node 2761, Decrypted Result: 2111
# Node 712, Decrypted Result: 4160
# Node 4807, Decrypted Result: 65
# Node 713, Decrypted Result: 4159
# Node 2765, Decrypted Result: 2107
# Node 720, Decrypted Result: 4152
# Node 721, Decrypted Result: 4151
# Node 2768, Decrypted Result: 2104
# Node 724, Decrypted Result: 4148
# Node 725, Decrypted Result: 4147
# Node 2779, Decrypted Result: 2093
# Node 4828, Decrypted Result: 44
# Node 4835, Decrypted Result: 37
# Node 2788, Decrypted Result: 2084
# Node 4837, Decrypted Result: 35
# Node 742, Decrypted Result: 4130
# Node 4839, Decrypted Result: 33
# Node 744, Decrypted Result: 4128
# Node 4840, Decrypted Result: 32
# Node 749, Decrypted Result: 4123
# Node 750, Decrypted Result: 4122
# Node 4851, Decrypted Result: 21
# Node 2805, Decrypted Result: 2067
# Node 4853, Decrypted Result: 19
# Node 4855, Decrypted Result: 17
# Node 4856, Decrypted Result: 16
# Node 759, Decrypted Result: 4113
# Node 762, Decrypted Result: 4110
# Node 4859, Decrypted Result: 13
# Node 2810, Decrypted Result: 2062
# Node 2812, Decrypted Result: 2060
# Node 4865, Decrypted Result: 7
# Node 4866, Decrypted Result: 6
# Node 4868, Decrypted Result: 4
# Node 773, Decrypted Result: 4099
# Node 2823, Decrypted Result: 2049
# Node 4872, Decrypted Result: 0
#
# Number 4872 found at iteration 458.
#
# Number 4872 was successfully found!
# Total Comparisons: 458
# Execution Time: 43.5526 seconds

# %%
#Same code just run one more time

import tenseal as ts
import random
import csv
import time

# Skip list node class
class SkipListNode:
    def __init__(self, value, level):
        self.value = value
        self.forward = [None] * (level + 1)

# Skip list class
class SkipList:
    def __init__(self, max_level, p):
        self.max_level = max_level
        self.p = p
        self.header = self._create_node(-1, max_level)
        self.level = 0

    def _create_node(self, value, level):
        return SkipListNode(value, level)

    def random_level(self):
        level = 0
        while random.random() < self.p and level < self.max_level:
            level += 1
        return level

    def insert(self, value):
        update = [None] * (self.max_level + 1)
        current = self.header

        for i in range(self.level, -1, -1):
            while current.forward[i] and current.forward[i].value < value:
                current = current.forward[i]
            update[i] = current

        level = self.random_level()
        if level > self.level:
            for i in range(self.level + 1, level + 1):
                update[i] = self.header
            self.level = level

        new_node = self._create_node(value, level)
        for i in range(level + 1):
            new_node.forward[i] = update[i].forward[i]
            update[i].forward[i] = new_node

    def get_elements(self):
        current = self.header.forward[0]
        elements = []
        while current:
            elements.append(current.value)
            current = current.forward[0]
        return elements

# Load skip list elements directly from Server.csv
server_file = "Server.csv"
server_numbers = []
with open(server_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    server_numbers = [int(row[0]) for row in reader]

# Since the file already represents a skip list, we consider server_numbers as the skip list elements.
print("Server skip list loaded with 1000 elements from Server.csv.")

# Set up BFV Homomorphic Encryption Context
def setup_bfv_context():
    context = ts.context(ts.SCHEME_TYPE.BFV, poly_modulus_degree=8192, plain_modulus=1032193)
    return context

# Encrypt value in BFV

def encrypt_value(context, value):
    return ts.bfv_vector(context, [value])

# Homomorphic Comparison
def server_compare(enc_target, skip_list_value, r, context):
    enc_r = ts.bfv_vector(context, [r])
    enc_value = ts.bfv_vector(context, [skip_list_value])
    result = enc_target - enc_value
    result = result * enc_r  # Multiply by r
    return result

# Search Functionality
def encrypted_search(server_numbers, client_value, context):
    print("\nStarting Homomorphic Search...")
    target_enc = encrypt_value(context, client_value)
    comparisons = 0
    visited = set()

    # Simulate skip list traversal
    for i, value in enumerate(server_numbers):
        if value in visited:  # Skip already visited nodes
            continue
        visited.add(value)

        r = random.randint(1, 100)  # Random r > 0
        encrypted_result = server_compare(target_enc, value, r, context)

        # Simulate sending encrypted result back to client
        decrypted_result = encrypted_result.decrypt()[0] // r
        print(f"Node {value}, Decrypted Result: {decrypted_result}")

        comparisons += 1
        if decrypted_result == 0:
            print(f"\nNumber {client_value} found at iteration {comparisons}.")
            return True, comparisons

        if decrypted_result < 0:  # Move left (simulate)
            break

    print(f"\nNumber {client_value} NOT found after {comparisons} comparisons.")
    return False, comparisons

# Client Logic
client_file = "Client.csv"
client_numbers = []
with open(client_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    client_numbers = [int(row[0]) for row in reader]

random_client_value = random.choice(client_numbers)
print(f"Client randomly selected number: {random_client_value}")

# Setup BFV Context
bfv_context = setup_bfv_context()

# Perform Encrypted Search
start_time = time.time()
found, total_comparisons = encrypted_search(server_numbers, random_client_value, bfv_context)
end_time = time.time()

# Display Results
if found:
    print(f"\nNumber {random_client_value} was successfully found!")
else:
    print(f"\nNumber {random_client_value} was not found in the skip list.")

print(f"Total Comparisons: {total_comparisons}")
print(f"Execution Time: {end_time - start_time:.4f} seconds")
# Out:
# Server skip list loaded with 1000 elements from Server.csv.
# Client randomly selected number: 2412
#
# Starting Homomorphic Search...
# Node 1, Decrypted Result: 2411
# Node 2053, Decrypted Result: 359
# Node 2054, Decrypted Result: 358
# Node 2058, Decrypted Result: 354
# Node 4107, Decrypted Result: -1695
#
# Number 2412 NOT found after 5 comparisons.
#
# Number 2412 was not found in the skip list.
# Total Comparisons: 5
# Execution Time: 0.5042 seconds

# %%
#Same code for above having parallel exceution for more numbers

import tenseal as ts
import random
import csv
import time
import multiprocessing as mp

# Skip list node class
class SkipListNode:
    def __init__(self, value, level):
        self.value = value
        self.forward = [None] * (level + 1)

# Skip list class
class SkipList:
    def __init__(self, max_level, p):
        self.max_level = max_level
        self.p = p
        self.header = self._create_node(-1, max_level)
        self.level = 0

    def _create_node(self, value, level):
        return SkipListNode(value, level)

    def random_level(self):
        level = 0
        while random.random() < self.p and level < self.max_level:
            level += 1
        return level

    def insert(self, value):
        update = [None] * (self.max_level + 1)
        current = self.header

        for i in range(self.level, -1, -1):
            while current.forward[i] and current.forward[i].value < value:
                current = current.forward[i]
            update[i] = current

        level = self.random_level()
        if level > self.level:
            for i in range(self.level + 1, level + 1):
                update[i] = self.header
            self.level = level

        new_node = self._create_node(value, level)
        for i in range(level + 1):
            new_node.forward[i] = update[i].forward[i]
            update[i].forward[i] = new_node

    def get_elements(self):
        current = self.header.forward[0]
        elements = []
        while current:
            elements.append(current.value)
            current = current.forward[0]
        return elements

# Load skip list elements directly from Server.csv
server_file = "Server.csv"
server_numbers = []
with open(server_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    server_numbers = [int(row[0]) for row in reader]

# Since the file already represents a skip list, we consider server_numbers as the skip list elements.
print("Server skip list loaded with 1000 elements from Server.csv.")

# Set up BFV Homomorphic Encryption Context
def setup_bfv_context():
    context = ts.context(ts.SCHEME_TYPE.BFV, poly_modulus_degree=8192, plain_modulus=1032193)
    return context

# Encrypt value in BFV

def encrypt_value(context, value):
    return ts.bfv_vector(context, [value])

# Homomorphic Comparison
def server_compare(enc_target, skip_list_value, r, context):
    enc_r = ts.bfv_vector(context, [r])
    enc_value = ts.bfv_vector(context, [skip_list_value])
    result = enc_target - enc_value
    result = result * enc_r  # Multiply by r
    return result

# Search Functionality
def encrypted_search(server_numbers, client_value, context, results, idx):
    print(f"\nStarting Homomorphic Search for Client Value {client_value}...")
    target_enc = encrypt_value(context, client_value)
    comparisons = 0
    visited = set()

    # Simulate skip list traversal
    for i, value in enumerate(server_numbers):
        if value in visited:  # Skip already visited nodes
            continue
        visited.add(value)

        r = random.randint(1, 100)  # Random r > 0
        encrypted_result = server_compare(target_enc, value, r, context)

        # Simulate sending encrypted result back to client
        decrypted_result = encrypted_result.decrypt()[0] // r
        print(f"Node {value}, Decrypted Result: {decrypted_result}")

        comparisons += 1
        if decrypted_result == 0:
            print(f"\nNumber {client_value} found at iteration {comparisons}.")
            results[idx] = (client_value, True, comparisons)
            return

        if decrypted_result < 0:  # Move left (simulate)
            break

    print(f"\nNumber {client_value} NOT found after {comparisons} comparisons.")
    results[idx] = (client_value, False, comparisons)

# Client Logic
client_file = "Client.csv"
client_numbers = []
with open(client_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    client_numbers = [int(row[0]) for row in reader]

random_client_values = random.sample(client_numbers, 10)
print(f"Client randomly selected 10 distinct numbers: {random_client_values}")

# Setup BFV Context
bfv_context = setup_bfv_context()

# Perform Parallel Encrypted Search
def parallel_search():
    manager = mp.Manager()
    results = manager.dict()
    processes = []

    start_time = time.time()
    for idx, value in enumerate(random_client_values):
        p = mp.Process(target=encrypted_search, args=(server_numbers, value, bfv_context, results, idx))
        processes.append(p)
        p.start()

    for p in processes:
        p.join()
    end_time = time.time()

    print("\nSearch Results:")
    for idx, result in results.items():
        print(f"Number: {result[0]}, Found: {result[1]}, Comparisons: {result[2]}")
    print(f"\nTotal Execution Time: {end_time - start_time:.4f} seconds")

if __name__ == "__main__":
    parallel_search()
# Out:
# Server skip list loaded with 1000 elements from Server.csv.
# Client randomly selected 10 distinct numbers: [2497, 4034, 1598, 3545, 2232, 2307, 1496, 3322, 896, 2412]
#
# Starting Homomorphic Search for Client Value 2497...
#
# Starting Homomorphic Search for Client Value 4034...
#
# Starting Homomorphic Search for Client Value 1598...
#
# Starting Homomorphic Search for Client Value 2232...
# Starting Homomorphic Search for Client Value 1496...
#
# Starting Homomorphic Search for Client Value 3322...
# Starting Homomorphic Search for Client Value 2307...
# Starting Homomorphic Search for Client Value 3545...
#
# Starting Homomorphic Search for Client Value 896...
#
#
#
# Node 1, Decrypted Result: 2496
# Node 1, Decrypted Result: 1597
#
# Starting Homomorphic Search for Client Value 2412...
# Node 1, Decrypted Result: 4033
# Node 1, Decrypted Result: 1495
# Node 1, Decrypted Result: 895
# Node 2053, Decrypted Result: 444
# Node 2053, Decrypted Result: -455
#
# Number 1598 NOT found after 2 comparisons.Node 1, Decrypted Result: 2411
#
# Node 1, Decrypted Result: 2231
# Node 1, Decrypted Result: 2306Node 1, Decrypted Result: 3321Node 2053, Decrypted Result: 1981
#
# Node 1, Decrypted Result: 3544
#
# Node 2053, Decrypted Result: -557
#
# Number 1496 NOT found after 2 comparisons.
# Node 2053, Decrypted Result: 359
# Node 2053, Decrypted Result: -1157Node 2054, Decrypted Result: 443
#
# Node 2053, Decrypted Result: 179Node 2054, Decrypted Result: 1980Node 2053, Decrypted Result: 1269
# Number 896 NOT found after 2 comparisons.Node 2053, Decrypted Result: 1492
#
#
#
# Node 2054, Decrypted Result: 358
#
# Node 2053, Decrypted Result: 254
# Node 2058, Decrypted Result: 439
# Node 2054, Decrypted Result: 1268Node 2058, Decrypted Result: 354Node 2058, Decrypted Result: 1976
#
#
# Node 2054, Decrypted Result: 1491
# Node 2054, Decrypted Result: 178
# Node 2054, Decrypted Result: 253
# Node 2058, Decrypted Result: 1264
# Node 2058, Decrypted Result: 1487Node 4107, Decrypted Result: -1610
#
#
# Number 2497 NOT found after 5 comparisons.
# Node 4107, Decrypted Result: -73
# Node 4107, Decrypted Result: -1695
#
# Number 4034 NOT found after 5 comparisons.Node 2058, Decrypted Result: 174
# Number 2412 NOT found after 5 comparisons.
#
#
# Node 2058, Decrypted Result: 249
# Node 4107, Decrypted Result: -562Node 4107, Decrypted Result: -785
#
#
# Number 3322 NOT found after 5 comparisons.
# Number 3545 NOT found after 5 comparisons.
#
# Node 4107, Decrypted Result: -1875
#
# Number 2232 NOT found after 5 comparisons.
# Node 4107, Decrypted Result: -1800
#
# Number 2307 NOT found after 5 comparisons.
#
# Search Results:
# Number: 1598, Found: False, Comparisons: 2
# Number: 1496, Found: False, Comparisons: 2
# Number: 896, Found: False, Comparisons: 2
# Number: 2497, Found: False, Comparisons: 5
# Number: 2412, Found: False, Comparisons: 5
# Number: 4034, Found: False, Comparisons: 5
# Number: 3322, Found: False, Comparisons: 5
# Number: 3545, Found: False, Comparisons: 5
# Number: 2232, Found: False, Comparisons: 5
# Number: 2307, Found: False, Comparisons: 5
#
# Total Execution Time: 0.8704 seconds

# %%
import tenseal as ts
import random
import csv
import time
import multiprocessing as mp

# Skip list node class
class SkipListNode:
    def __init__(self, value, level):
        self.value = value
        self.forward = [None] * (level + 1)

# Skip list class
class SkipList:
    def __init__(self, max_level, p):
        self.max_level = max_level
        self.p = p
        self.header = self._create_node(-1, max_level)
        self.level = 0

    def _create_node(self, value, level):
        return SkipListNode(value, level)

    def random_level(self):
        level = 0
        while random.random() < self.p and level < self.max_level:
            level += 1
        return level

    def insert(self, value):
        update = [None] * (self.max_level + 1)
        current = self.header

        for i in range(self.level, -1, -1):
            while current.forward[i] and current.forward[i].value < value:
                current = current.forward[i]
            update[i] = current

        level = self.random_level()
        if level > self.level:
            for i in range(self.level + 1, level + 1):
                update[i] = self.header
            self.level = level

        new_node = self._create_node(value, level)
        for i in range(level + 1):
            new_node.forward[i] = update[i].forward[i]
            update[i].forward[i] = new_node

    def get_elements(self):
        current = self.header.forward[0]
        elements = []
        while current:
            elements.append(current.value)
            current = current.forward[0]
        return elements

# Load skip list elements directly from Server.csv
server_file = "Server.csv"
server_numbers = []
with open(server_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    server_numbers = [int(row[0]) for row in reader]

# Since the file already represents a skip list, we consider server_numbers as the skip list elements.
print("Server skip list loaded with 1000 elements from Server.csv.")

# Set up BFV Homomorphic Encryption Context
def setup_bfv_context():
    context = ts.context(ts.SCHEME_TYPE.BFV, poly_modulus_degree=8192, plain_modulus=1032193)
    return context

# Encrypt value in BFV
def encrypt_value(context, value):
    return ts.bfv_vector(context, [value])

# Homomorphic Comparison
def server_compare(enc_target, skip_list_value, r, context):
    enc_r = ts.bfv_vector(context, [r])
    enc_value = ts.bfv_vector(context, [skip_list_value])
    result = enc_target - enc_value
    result = result * enc_r  # Multiply by r
    return result

# Search Functionality
def encrypted_search(server_numbers, client_value, context, results, idx):
    print(f"\nStarting Homomorphic Search for Client Value {client_value}...")
    target_enc = encrypt_value(context, client_value)
    comparisons = 0
    visited = set()

    # Skip list traversal logic
    current_index = 0
    while current_index < len(server_numbers):
        value = server_numbers[current_index]
        if value in visited:  # Skip already visited nodes
            current_index += 1
            continue
        visited.add(value)

        r = random.randint(1, 100)  # Random r > 0
        encrypted_result = server_compare(target_enc, value, r, context)

        # Simulate sending encrypted result back to client
        decrypted_result = encrypted_result.decrypt()[0] // r
        print(f"Iteration {comparisons + 1}: Node {value}, Decrypted Result: {decrypted_result}")

        comparisons += 1
        if decrypted_result == 0:
            print(f"\nNumber {client_value} found at iteration {comparisons}.")
            results[idx] = (client_value, True, comparisons)
            return

        if decrypted_result < 0:  # Move left
            current_index -= 1
        else:  # Move right
            current_index += 1

    print(f"\nNumber {client_value} NOT found after {comparisons} comparisons.")
    results[idx] = (client_value, False, comparisons)

# Client Logic
client_file = "Client.csv"
client_numbers = []
with open(client_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    client_numbers = [int(row[0]) for row in reader]

print(f"Client has {len(client_numbers)} numbers to search.")

# Setup BFV Context
bfv_context = setup_bfv_context()

# Perform Parallel Encrypted Search
def parallel_search():
    manager = mp.Manager()
    results = manager.dict()
    processes = []

    start_time = time.time()
    for idx, value in enumerate(client_numbers):
        p = mp.Process(target=encrypted_search, args=(server_numbers, value, bfv_context, results, idx))
        processes.append(p)
        p.start()

    for p in processes:
        p.join()
    end_time = time.time()

    print("\nSearch Results:")
    for idx, result in results.items():
        print(f"Number: {result[0]}, Found: {result[1]}, Comparisons: {result[2]}")
    print(f"\nTotal Execution Time: {end_time - start_time:.4f} seconds")

if __name__ == "__main__":
    parallel_search()
# Out:
# Server skip list loaded with 1000 elements from Server.csv.
# Client has 100 numbers to search.
#
# Starting Homomorphic Search for Client Value 1266...
#
# Starting Homomorphic Search for Client Value 4513...
#
# Starting Homomorphic Search for Client Value 1338...
#
# Starting Homomorphic Search for Client Value 4501...
#
# Starting Homomorphic Search for Client Value 1424...
#
# Starting Homomorphic Search for Client Value 3967...
#
# Starting Homomorphic Search for Client Value 2442...
# Starting Homomorphic Search for Client Value 612...
#
#
# Starting Homomorphic Search for Client Value 4242...
#
# Starting Homomorphic Search for Client Value 658...
#
# Starting Homomorphic Search for Client Value 2236...
#
# Starting Homomorphic Search for Client Value 535...
#
# Starting Homomorphic Search for Client Value 3432...
#
# Starting Homomorphic Search for Client Value 2143...
#
# Starting Homomorphic Search for Client Value 2894...
#
# Starting Homomorphic Search for Client Value 680...Iteration 1: Node 4097, Decrypted Result: 416Iteration 1: Node 4097, Decrypted Result: -2831
#
#
#
# Starting Homomorphic Search for Client Value 4692...Iteration 1: Node 4097, Decrypted Result: 404Iteration 1: Node 4097, Decrypted Result: -130
# Iteration 1: Node 4097, Decrypted Result: -2759
#
#
# Iteration 1: Node 4097, Decrypted Result: -2673
# Starting Homomorphic Search for Client Value 2097...
#
#
# Starting Homomorphic Search for Client Value 1891...
#
# Starting Homomorphic Search for Client Value 4593...Iteration 1: Node 4097, Decrypted Result: -1655
#
#
# Starting Homomorphic Search for Client Value 4924...Iteration 1: Node 4097, Decrypted Result: -3485Iteration 1: Node 4097, Decrypted Result: 145
#
# Starting Homomorphic Search for Client Value 856...
# Iteration 1: Node 4097, Decrypted Result: -3439
#
#
# Iteration 1: Node 4097, Decrypted Result: -1861Iteration 1: Node 4097, Decrypted Result: -3562
# Starting Homomorphic Search for Client Value 1956...
#
#
#
# Starting Homomorphic Search for Client Value 228...Iteration 1: Node 4097, Decrypted Result: -665
#
# Iteration 1: Node 4097, Decrypted Result: -1954Iteration 2: Node 4094, Decrypted Result: -2828
# Starting Homomorphic Search for Client Value 716...
#
#
#
# Starting Homomorphic Search for Client Value 4824...Iteration 2: Node 2050, Decrypted Result: 2463Iteration 2: Node 4094, Decrypted Result: -127Iteration 2: Node 2050, Decrypted Result: 2451
#
#
#
#
# Starting Homomorphic Search for Client Value 997...Iteration 1: Node 4097, Decrypted Result: -1203Iteration 2: Node 4094, Decrypted Result: -2756Iteration 1: Node 4097, Decrypted Result: -3417
#
#
#
#
# Starting Homomorphic Search for Client Value 771...Iteration 2: Node 4094, Decrypted Result: -2670
#
# Iteration 1: Node 4097, Decrypted Result: 595
# Starting Homomorphic Search for Client Value 1722...
#
# Iteration 1: Node 4097, Decrypted Result: -2000Iteration 1: Node 4097, Decrypted Result: -2206
# Starting Homomorphic Search for Client Value 999...Iteration 2: Node 4094, Decrypted Result: -1652Iteration 1: Node 4097, Decrypted Result: 496
#
#
#
#
# Iteration 2: Node 2050, Decrypted Result: 2192
# Iteration 2: Node 4094, Decrypted Result: -3436
# Iteration 2: Node 4094, Decrypted Result: -3482
# Iteration 2: Node 4094, Decrypted Result: -1858
# Starting Homomorphic Search for Client Value 6...Iteration 1: Node 4097, Decrypted Result: 827
#
#
#
# Starting Homomorphic Search for Client Value 3696...Iteration 2: Node 4094, Decrypted Result: -3559Iteration 2: Node 4094, Decrypted Result: -662
# Starting Homomorphic Search for Client Value 4469...
# Iteration 1: Node 4097, Decrypted Result: -2141
#
#
#
# Starting Homomorphic Search for Client Value 918...Iteration 1: Node 4097, Decrypted Result: -3241
# Iteration 2: Node 4094, Decrypted Result: -1951
#
#
# Iteration 3: Node 4093, Decrypted Result: -2827
#
# Starting Homomorphic Search for Client Value 2847...Iteration 3: Node 3, Decrypted Result: 4510Iteration 1: Node 4097, Decrypted Result: -3869Iteration 3: Node 4093, Decrypted Result: -126
#
#
# Iteration 3: Node 3, Decrypted Result: 4498Iteration 1: Node 4097, Decrypted Result: -3381
#
#
#
# Starting Homomorphic Search for Client Value 2967...
# Starting Homomorphic Search for Client Value 1272...
# Iteration 3: Node 4093, Decrypted Result: -2669Iteration 2: Node 4094, Decrypted Result: -3414Iteration 2: Node 4094, Decrypted Result: -1200Iteration 1: Node 4097, Decrypted Result: 727
#
#
#
#
# Iteration 2: Node 2050, Decrypted Result: 2642
# Starting Homomorphic Search for Client Value 1163...
# Iteration 1: Node 4097, Decrypted Result: -3100
#
# Iteration 3: Node 4093, Decrypted Result: -1651Iteration 2: Node 4094, Decrypted Result: -2203Iteration 2: Node 2050, Decrypted Result: 2543
#
#
#
# Starting Homomorphic Search for Client Value 589...Iteration 3: Node 4093, Decrypted Result: -2755Iteration 1: Node 4097, Decrypted Result: -3326
#
#
#
# Iteration 98: Node 165, Decrypted Result: 4428Iteration 114: Node 2252, Decrypted Result: 2217
#
# Iteration 114: Node 3831, Decrypted Result: -3298
#
# Iteration 112: Node 1787, Decrypted Result: -869
# Iteration 108: Node 3845, Decrypted Result: -2215
#
# Iteration 99: Node 1820, Decrypted Result: -736
# Iteration 108: Node 2232, Decrypted Result: 303
#
#
# Iteration 126: Node 2190, Decrypted Result: -243
#
#
#
#
# Iteration 93: Node 2208, Decrypted Result: 2629
#
# Iteration 109: Node 1795, Decrypted Result: -371
# Iteration 109: Node 1795, Decrypted Result: -129
# Iteration 102: Node 169, Decrypted Result: 3668
#
# Iteration 103: Node 1812, Decrypted Result: -1154
#
#
#
# Iteration 112: Node 1787, Decrypted Result: -1559
# Iteration 113: Node 3832, Decrypted Result: -3458Iteration 84: Node 1857, Decrypted Result: -371Iteration 111: Node 3835, Decrypted Result: -3114Iteration 111: Node 3835, Decrypted Result: -3155Iteration 100: Node 4260, Decrypted Result: -1818
# Iteration 105: Node 3849, Decrypted Result: -3123Iteration 113: Node 4297, Decrypted Result: -55Iteration 110: Node 1788, Decrypted Result: -1199
# Iteration 123: Node 2263, Decrypted Result: 704
# Iteration 100: Node 3866, Decrypted Result: -2177Iteration 106: Node 2228, Decrypted Result: 1482
#
# Iteration 99: Node 169, Decrypted Result: 4638Iteration 102: Node 1813, Decrypted Result: -1278
# Iteration 90: Node 150, Decrypted Result: 3108

# %%
import tenseal as ts
import random
import csv
import time
import multiprocessing as mp

# Skip list node class
class SkipListNode:
    def __init__(self, value, level):
        self.value = value
        self.forward = [None] * (level + 1)

# Skip list class
class SkipList:
    def __init__(self, max_level, p):
        self.max_level = max_level
        self.p = p
        self.header = self._create_node(-1, max_level)
        self.level = 0

    def _create_node(self, value, level):
        return SkipListNode(value, level)

    def random_level(self):
        level = 0
        while random.random() < self.p and level < self.max_level:
            level += 1
        return level

    def insert(self, value):
        update = [None] * (self.max_level + 1)
        current = self.header

        for i in range(self.level, -1, -1):
            while current.forward[i] and current.forward[i].value < value:
                current = current.forward[i]
            update[i] = current

        level = self.random_level()
        if level > self.level:
            for i in range(self.level + 1, level + 1):
                update[i] = self.header
            self.level = level

        new_node = self._create_node(value, level)
        for i in range(level + 1):
            new_node.forward[i] = update[i].forward[i]
            update[i].forward[i] = new_node

    def get_elements(self):
        current = self.header.forward[0]
        elements = []
        while current:
            elements.append(current.value)
            current = current.forward[0]
        return elements

# Load skip list elements directly from Server.csv
server_file = "Server.csv"
server_numbers = []
with open(server_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    server_numbers = [int(row[0]) for row in reader]

# Since the file already represents a skip list, we consider server_numbers as the skip list elements.
print("Server skip list loaded with 1000 elements from Server.csv.")

# Set up BFV Homomorphic Encryption Context
def setup_bfv_context():
    context = ts.context(ts.SCHEME_TYPE.BFV, poly_modulus_degree=8192, plain_modulus=1032193)
    return context

# Encrypt value in BFV
def encrypt_value(context, value):
    return ts.bfv_vector(context, [value])

# Homomorphic Comparison
def server_compare(enc_target, skip_list_value, r, context):
    enc_r = ts.bfv_vector(context, [r])
    enc_value = ts.bfv_vector(context, [skip_list_value])
    result = enc_target - enc_value
    result = result * enc_r  # Multiply by r
    return result

# Search Functionality
def encrypted_search(server_numbers, client_value, context, results, idx, common_numbers):
    print(f"\nStarting Homomorphic Search for Client Value {client_value}...")
    target_enc = encrypt_value(context, client_value)
    comparisons = 0
    visited = set()

    # Simulate skip list traversal
    for i, value in enumerate(server_numbers):
        if value in visited:  # Skip already visited nodes
            continue
        visited.add(value)

        r = random.randint(1, 100)  # Random r > 0
        encrypted_result = server_compare(target_enc, value, r, context)

        # Simulate sending encrypted result back to client
        decrypted_result = encrypted_result.decrypt()[0] // r
        print(f"Node {value}, Decrypted Result: {decrypted_result}")

        comparisons += 1
        if decrypted_result == 0:
            print(f"\nNumber {client_value} found at iteration {comparisons}.")
            results[idx] = (client_value, True, comparisons)
            common_numbers.append(client_value)  # Add to common numbers
            return

        if decrypted_result < 0:  # Move left (simulate)
            break

    print(f"\nNumber {client_value} NOT found after {comparisons} comparisons.")
    results[idx] = (client_value, False, comparisons)

# Client Logic
client_file = "Client.csv"
client_numbers = []
with open(client_file, "r") as file:
    reader = csv.reader(file)
    next(reader)  # Skip header
    client_numbers = [int(row[0]) for row in reader]

print(f"Client has {len(client_numbers)} numbers to search.")

# Setup BFV Context
bfv_context = setup_bfv_context()

# Perform Parallel Encrypted Search
def parallel_search():
    manager = mp.Manager()
    results = manager.dict()
    common_numbers = manager.list()  # Shared list to store common numbers
    processes = []

    start_time = time.time()
    for idx, value in enumerate(client_numbers):
        p = mp.Process(target=encrypted_search, args=(server_numbers, value, bfv_context, results, idx, common_numbers))
        processes.append(p)
        p.start()

    for p in processes:
        p.join()
    end_time = time.time()

    print("\nSearch Results:")
    for idx, result in results.items():
        print(f"Number: {result[0]}, Found: {result[1]}, Comparisons: {result[2]}")
    
    print(f"\nTotal Execution Time: {end_time - start_time:.4f} seconds")

    # Display the common numbers
    print("\nCommon Numbers between Client and Server:")
    if common_numbers:
        print(common_numbers)
    else:
        print("No common numbers found.")

if __name__ == "__main__":
    parallel_search()
# Out:
# Server skip list loaded with 1000 elements from Server.csv.
# Client has 100 numbers to search.
#
# Starting Homomorphic Search for Client Value 1266...
#
# Starting Homomorphic Search for Client Value 4513...
#
# Starting Homomorphic Search for Client Value 1338...
#
# Starting Homomorphic Search for Client Value 4501...
#
# Starting Homomorphic Search for Client Value 1424...
#
# Starting Homomorphic Search for Client Value 3967...
#
# Starting Homomorphic Search for Client Value 2442...
#
# Starting Homomorphic Search for Client Value 612...
#
# Starting Homomorphic Search for Client Value 4242...
#
# Starting Homomorphic Search for Client Value 658...
#
# Starting Homomorphic Search for Client Value 2236...
#
# Starting Homomorphic Search for Client Value 535...
#
# Starting Homomorphic Search for Client Value 3432...
# Node 4097, Decrypted Result: -2831
# Starting Homomorphic Search for Client Value 2143...Node 4097, Decrypted Result: -2759Node 4097, Decrypted Result: 416
#
#
# Node 4097, Decrypted Result: -2673Node 4097, Decrypted Result: 404
# Number 1266 NOT found after 1 comparisons.
# Number 1338 NOT found after 1 comparisons.
#
#
#
#
#
# Number 1424 NOT found after 1 comparisons.
#
# Starting Homomorphic Search for Client Value 2894...
#
# Starting Homomorphic Search for Client Value 680...Node 4097, Decrypted Result: -130
#
# Number 3967 NOT found after 1 comparisons.
#
# Node 4097, Decrypted Result: -3485
# Starting Homomorphic Search for Client Value 4692...
#
# Number 612 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 2097...
# Node 4097, Decrypted Result: -3439
# Starting Homomorphic Search for Client Value 1891...Node 4097, Decrypted Result: -1655
#
#
# Number 658 NOT found after 1 comparisons.
# Number 2442 NOT found after 1 comparisons.
#
#
# Node 4097, Decrypted Result: -1861
#
# Number 2236 NOT found after 1 comparisons.Node 4097, Decrypted Result: 145
# Starting Homomorphic Search for Client Value 4593...
# Node 4097, Decrypted Result: -3562
#
#
# Number 535 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 4924...Node 2050, Decrypted Result: 2451Node 2050, Decrypted Result: 2463Node 4097, Decrypted Result: -665
#
#
#
#
# Number 3432 NOT found after 1 comparisons.
#
# Starting Homomorphic Search for Client Value 856...
# Node 4097, Decrypted Result: -1954
#
# Starting Homomorphic Search for Client Value 1956...
# Number 2143 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 228...
# Node 4097, Decrypted Result: -1203
# Starting Homomorphic Search for Client Value 716...Node 4097, Decrypted Result: -3417
#
#
# Number 680 NOT found after 1 comparisons.
# Number 2894 NOT found after 1 comparisons.
#
#
#
# Starting Homomorphic Search for Client Value 4824...
#
# Starting Homomorphic Search for Client Value 997...
#
# Starting Homomorphic Search for Client Value 771...
#
# Starting Homomorphic Search for Client Value 1722...
# Node 4097, Decrypted Result: -2000
# Node 4097, Decrypted Result: 595
#
# Number 2097 NOT found after 1 comparisons.Node 4097, Decrypted Result: 496Node 4097, Decrypted Result: -2206Node 3, Decrypted Result: 4510
#
#
#
#
# Number 1891 NOT found after 1 comparisons.
# Starting Homomorphic Search for Client Value 999...
#
# Node 4097, Decrypted Result: 827
# Node 2050, Decrypted Result: 2192Node 4097, Decrypted Result: -2141Node 4097, Decrypted Result: -3869
#
#
#
# Number 1956 NOT found after 1 comparisons.
# Number 228 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 3696...Node 3, Decrypted Result: 4498
#
#
# Starting Homomorphic Search for Client Value 918...
#
# Starting Homomorphic Search for Client Value 2847...
# Node 4097, Decrypted Result: 727
# Node 4097, Decrypted Result: -3100Node 4097, Decrypted Result: -3241
#
#
# Number 997 NOT found after 1 comparisons.
# Number 856 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 2967...Node 4097, Decrypted Result: -3381Node 2050, Decrypted Result: 2543Node 4101, Decrypted Result: 412
#
#
#
#
# Number 716 NOT found after 1 comparisons.
# Node 4097, Decrypted Result: -3326
# Starting Homomorphic Search for Client Value 1272...
#
# Number 771 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 1163...Node 2050, Decrypted Result: 2874Node 2050, Decrypted Result: 2642
#
#
#
# Starting Homomorphic Search for Client Value 589...Node 3, Decrypted Result: 4239
#
# Node 4097, Decrypted Result: -3098Node 4097, Decrypted Result: -2375
#
# Starting Homomorphic Search for Client Value 1630...
# Number 999 NOT found after 1 comparisons.
#
#
# Number 1722 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 1191...
#
# Starting Homomorphic Search for Client Value 489...
#
# Starting Homomorphic Search for Client Value 4352...Node 4097, Decrypted Result: -401
#
# Number 3696 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 3950...Node 4101, Decrypted Result: 400Node 4097, Decrypted Result: -3179Node 2050, Decrypted Result: 2774
# Node 2053, Decrypted Result: 2460Node 3, Decrypted Result: 4590
#
#
#
#
#
# Number 918 NOT found after 1 comparisons.
#
# Starting Homomorphic Search for Client Value 4837...
#
# Starting Homomorphic Search for Client Value 681...Node 3, Decrypted Result: 4689Node 3, Decrypted Result: 4921Node 4097, Decrypted Result: -1130Node 4097, Decrypted Result: -1250
#
#
#
#
#
# Number 2847 NOT found after 1 comparisons.
#
# Number 2967 NOT found after 1 comparisons.
# Node 4101, Decrypted Result: 141
# Starting Homomorphic Search for Client Value 3837...Node 4097, Decrypted Result: -2825
#
#
# Number 1272 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 1774...Node 4097, Decrypted Result: -3508Node 4097, Decrypted Result: -2934
#
#
# Number 1163 NOT found after 1 comparisons.
# Number 589 NOT found after 1 comparisons.
#
#
#
# Starting Homomorphic Search for Client Value 4350...
# Starting Homomorphic Search for Client Value 4469...
#
#
# Starting Homomorphic Search for Client Value 6...
# Starting Homomorphic Search for Client Value 912...Node 4097, Decrypted Result: -2467
#
# Number 1630 NOT found after 1 comparisons.
#
#
#
# Starting Homomorphic Search for Client Value 2213...Node 4097, Decrypted Result: -2906
#
# Number 1191 NOT found after 1 comparisons.
#
# Node 3, Decrypted Result: 4821Node 4101, Decrypted Result: 492Node 2055, Decrypted Result: 2458
#
#
# Node 4097, Decrypted Result: 255
#
# Starting Homomorphic Search for Client Value 2512...
# Node 4097, Decrypted Result: -3608
# Starting Homomorphic Search for Client Value 4807...
#
#
# Number 489 NOT found after 1 comparisons.
#
# Starting Homomorphic Search for Client Value 1947...Node 2053, Decrypted Result: 2189
#
# Node 2053, Decrypted Result: 2448Node 4101, Decrypted Result: 591
#
# Starting Homomorphic Search for Client Value 374...Node 4097, Decrypted Result: -3416Node 4097, Decrypted Result: -147
#
#
#
# Number 681 NOT found after 1 comparisons.
#
#
# Number 3950 NOT found after 1 comparisons.
# Node 4101, Decrypted Result: 823
#
# Starting Homomorphic Search for Client Value 3710...Node 4097, Decrypted Result: 740
#
#
# Starting Homomorphic Search for Client Value 3309...Node 4097, Decrypted Result: -260
#
# Number 3837 NOT found after 1 comparisons.
#
# Node 4097, Decrypted Result: -2323
# Starting Homomorphic Search for Client Value 4114...
#
# Number 1774 NOT found after 1 comparisons.
#
# Node 4097, Decrypted Result: 253
# Starting Homomorphic Search for Client Value 414...
# Node 4097, Decrypted Result: -4091Node 4097, Decrypted Result: -3185
#
#
# Number 6 NOT found after 1 comparisons.
#
# Number 912 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 3518...Node 2050, Decrypted Result: 2302Node 2053, Decrypted Result: 2540Node 4097, Decrypted Result: 372Node 8, Decrypted Result: 4505
#
#
#
#
#
# Starting Homomorphic Search for Client Value 3741...Node 4097, Decrypted Result: -1585Node 4101, Decrypted Result: 723
#
#
# Number 2512 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 1898...
#
# Starting Homomorphic Search for Client Value 1264...
# Node 4097, Decrypted Result: -3723
#
#
# Number 374 NOT found after 1 comparisons.
# Starting Homomorphic Search for Client Value 2319...Node 4097, Decrypted Result: -2150Node 2055, Decrypted Result: 2187
# Node 4097, Decrypted Result: -1884
#
# Number 1947 NOT found after 1 comparisons.
#
#
#
# Number 2213 NOT found after 1 comparisons.
#
# Starting Homomorphic Search for Client Value 3689...Node 4097, Decrypted Result: -788
#
# Number 3309 NOT found after 1 comparisons.
#
# Node 4097, Decrypted Result: 710
# Starting Homomorphic Search for Client Value 595...Node 2053, Decrypted Result: 2639
#
#
#
# Starting Homomorphic Search for Client Value 4781...Node 3, Decrypted Result: 4349Node 4097, Decrypted Result: -387Node 2053, Decrypted Result: 2871
#
#
#
# Number 3710 NOT found after 1 comparisons.Node 4097, Decrypted Result: 17
#
#
#
# Starting Homomorphic Search for Client Value 1768...Node 2055, Decrypted Result: 2446Node 2050, Decrypted Result: 2787
#
#
#
# Starting Homomorphic Search for Client Value 2706...Node 2050, Decrypted Result: 2300Node 4097, Decrypted Result: -3683
#
#
#
# Number 414 NOT found after 1 comparisons.Node 4110, Decrypted Result: 403Node 2050, Decrypted Result: 2419
# Starting Homomorphic Search for Client Value 1410...
#
#
#
# Starting Homomorphic Search for Client Value 2491...
#
# Node 2055, Decrypted Result: 2538
# Starting Homomorphic Search for Client Value 68...
#
# Node 4097, Decrypted Result: -356
# Node 4097, Decrypted Result: -579
# Number 3741 NOT found after 1 comparisons.
#
# Starting Homomorphic Search for Client Value 3258...Node 2053, Decrypted Result: 2771
# Number 3518 NOT found after 1 comparisons.
#
# Node 8, Decrypted Result: 4234
#
#
#
# Starting Homomorphic Search for Client Value 387...
#
# Starting Homomorphic Search for Client Value 1689...Node 2050, Decrypted Result: 2757
#
# Node 2050, Decrypted Result: 2064Node 4097, Decrypted Result: -408
# Starting Homomorphic Search for Client Value 2299...Node 4101, Decrypted Result: 251Node 4097, Decrypted Result: -2199
#
#
#
#
# Node 4097, Decrypted Result: -3502
# Number 3689 NOT found after 1 comparisons.
# Number 1898 NOT found after 1 comparisons.
#
#
# Number 595 NOT found after 1 comparisons.
#
# Node 2055, Decrypted Result: 2637
# Starting Homomorphic Search for Client Value 4302...Node 4097, Decrypted Result: -2833
# Node 4097, Decrypted Result: 684
#
#
# Number 1264 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 1277...Node 3, Decrypted Result: 4466Node 4097, Decrypted Result: -2329Node 4097, Decrypted Result: -1778
#
#
#
# Number 2319 NOT found after 1 comparisons.
# Number 1768 NOT found after 1 comparisons.
#
#
#
# Starting Homomorphic Search for Client Value 2307...
# Node 4097, Decrypted Result: -1391
# Starting Homomorphic Search for Client Value 1666...
# Node 2055, Decrypted Result: 2869
#
# Number 2706 NOT found after 1 comparisons.
#
# Node 4110, Decrypted Result: 132
# Starting Homomorphic Search for Client Value 425...Node 2055, Decrypted Result: 2769Node 4097, Decrypted Result: -4029
#
#
#
#
# Number 68 NOT found after 1 comparisons.
# Node 3, Decrypted Result: 4347
#
# Starting Homomorphic Search for Client Value 4949...Node 3, Decrypted Result: 4834
# Node 4097, Decrypted Result: -2687
#
#
# Number 1410 NOT found after 1 comparisons.
# Starting Homomorphic Search for Client Value 2437...Node 3, Decrypted Result: 4804Node 8, Decrypted Result: 4493Node 4097, Decrypted Result: -3710
#
#
#
#
# Number 387 NOT found after 1 comparisons.
#
# Node 8, Decrypted Result: 4585
# Node 3, Decrypted Result: 4111
# Starting Homomorphic Search for Client Value 721...Node 2053, Decrypted Result: 2299Node 4097, Decrypted Result: -2408Node 15, Decrypted Result: 4498
#
# Node 8, Decrypted Result: 4684
#
#
# Number 1689 NOT found after 1 comparisons.
#
#
# Node 4097, Decrypted Result: -839Node 4097, Decrypted Result: -1606
# Starting Homomorphic Search for Client Value 2535...
#
#
#
# Number 2491 NOT found after 1 comparisons.
# Number 3258 NOT found after 1 comparisons.
#
#
# Starting Homomorphic Search for Client Value 726...
# Node 4097, Decrypted Result: -1798
# Starting Homomorphic Search for Client Value 597...Node 2050, Decrypted Result: 2731
#
#
# Number 2299 NOT found after 1 comparisons.
#
# Node 8, Decrypted Result: 4816Node 4097, Decrypted Result: 205
# Starting Homomorphic Search for Client Value 4904...
#
#
#
# Starting Homomorphic Search for Client Value 201...
# Node 4097, Decrypted Result: -3672Node 4101, Decrypted Result: 368Node 4097, Decrypted Result: -2431Node 4097, Decrypted Result: -1790
# Starting Homomorphic Search for Client Value 3757...
#
#
#
# Node 15, Decrypted Result: 4227
# Number 1666 NOT found after 1 comparisons.
# Number 425 NOT found after 1 comparisons.
# Number 2307 NOT found after 1 comparisons.
#
#
#
#
#
# Starting Homomorphic Search for Client Value 4397...Node 4097, Decrypted Result: -2820Node 4101, Decrypted Result: 706Node 4101, Decrypted Result: 249
#
#
#
#
# Number 1277 NOT found after 1 comparisons.Node 8, Decrypted Result: 4916
# Node 4101, Decrypted Result: 13
#
# Node 4110, Decrypted Result: 582
# Starting Homomorphic Search for Client Value 3927...Node 4097, Decrypted Result: 852
#
#
# Node 4097, Decrypted Result: -1660
#
# Starting Homomorphic Search for Client Value 3236...
# Number 2437 NOT found after 1 comparisons.
# Node 4101, Decrypted Result: 736
# Node 2055, Decrypted Result: 2297
#
#
# Starting Homomorphic Search for Client Value 1387...
# Node 4097, Decrypted Result: -1562Node 4110, Decrypted Result: 391Node 3, Decrypted Result: 4778Node 4110, Decrypted Result: 483
#
#
#
# Node 17, Decrypted Result: 4496
# Number 2535 NOT found after 1 comparisons.
#
# Node 4097, Decrypted Result: -3371
#
# Number 726 NOT found after 1 comparisons.
# Node 4110, Decrypted Result: 714
# Starting Homomorphic Search for Client Value 533...
#
#
# Starting Homomorphic Search for Client Value 4147...
#
# Starting Homomorphic Search for Client Value 1486...Node 2053, Decrypted Result: 2416Node 4097, Decrypted Result: 807Node 4097, Decrypted Result: -3376
#
#
#
#
# Starting Homomorphic Search for Client Value 1838...Node 2053, Decrypted Result: 2754Node 2053, Decrypted Result: 2061Node 4097, Decrypted Result: -3500
#
# Number 721 NOT found after 1 comparisons.
#
#
#
# Number 597 NOT found after 1 comparisons.
#
# Node 17, Decrypted Result: 4225
# Starting Homomorphic Search for Client Value 1504...Node 2050, Decrypted Result: 2252Node 15, Decrypted Result: 4677
#
#
# Node 4097, Decrypted Result: -3896
#
#
# Number 201 NOT found after 1 comparisons.
#
# Starting Homomorphic Search for Client Value 1084...
# Node 4097, Decrypted Result: 300
# Node 8, Decrypted Result: 4344
# Node 2053, Decrypted Result: 2297
# Node 4097, Decrypted Result: -861Node 4101, Decrypted Result: 680Node 4110, Decrypted Result: 814
#
#
# Number 3236 NOT found after 1 comparisons.
#
# Node 4097, Decrypted Result: -340Node 2050, Decrypted Result: 2899
#
#
# Number 3757 NOT found after 1 comparisons.
# Node 2053, Decrypted Result: 2784
# Node 15, Decrypted Result: 4809
# Node 4097, Decrypted Result: -170
#
# Number 3927 NOT found after 1 comparisons.
# Node 2055, Decrypted Result: 2414Node 2050, Decrypted Result: 2854
#
# Node 15, Decrypted Result: 4578
# Node 4114, Decrypted Result: 128Node 4097, Decrypted Result: -3564
#
#
# Number 533 NOT found after 1 comparisons.
# Node 4097, Decrypted Result: -2710
#
# Number 1387 NOT found after 1 comparisons.
# Node 4097, Decrypted Result: 50Node 15, Decrypted Result: 4486
#
# Node 4114, Decrypted Result: 399Node 4097, Decrypted Result: -2259Node 4097, Decrypted Result: -2611
#
#
#
# Number 1486 NOT found after 1 comparisons.
# Number 1838 NOT found after 1 comparisons.
#
# Node 2050, Decrypted Result: 2347
# Node 2055, Decrypted Result: 2752
# Node 4110, Decrypted Result: 242
# Node 4097, Decrypted Result: -3013
#
# Number 1084 NOT found after 1 comparisons.
# Node 2055, Decrypted Result: 2059
# Node 2053, Decrypted Result: 2728
# Node 17, Decrypted Result: 4675
# Node 3, Decrypted Result: 4299
# Node 17, Decrypted Result: 4807Node 15, Decrypted Result: 4909
#
# Node 2055, Decrypted Result: 2295
# Node 19, Decrypted Result: 4223Node 8, Decrypted Result: 4461
#
# Node 2055, Decrypted Result: 2782Node 4097, Decrypted Result: -2593
#
#
# Number 1504 NOT found after 1 comparisons.
# Node 3, Decrypted Result: 4946Node 2050, Decrypted Result: 2097
#
# Node 17, Decrypted Result: 4576Node 3, Decrypted Result: 4394
#
# Node 19, Decrypted Result: 4494
# Node 3, Decrypted Result: 4901
# Node 8, Decrypted Result: 4799
# Node 2055, Decrypted Result: 2726
# Node 15, Decrypted Result: 4337Node 17, Decrypted Result: 4484
#
# Node 4114, Decrypted Result: 710
# Node 2069, Decrypted Result: 2173Node 4110, Decrypted Result: 359
#
# Node 17, Decrypted Result: 4907
# Node 8, Decrypted Result: 4106
# Node 4101, Decrypted Result: 201
# Node 8, Decrypted Result: 4342
# Node 4114, Decrypted Result: 578
# Node 3, Decrypted Result: 4144Node 4114, Decrypted Result: 479Node 4101, Decrypted Result: 296
#
#
# Node 8, Decrypted Result: 4773Node 4101, Decrypted Result: 848
#
# Node 8, Decrypted Result: 4829
# Node 17, Decrypted Result: 4335Node 4110, Decrypted Result: 697
#
# Node 19, Decrypted Result: 4805
# Node 4114, Decrypted Result: 387
# Node 15, Decrypted Result: 4454Node 23, Decrypted Result: 4219Node 2069, Decrypted Result: 2444
#
#
# Node 4101, Decrypted Result: 803
# Node 2053, Decrypted Result: 2249
# Node 19, Decrypted Result: 4574Node 2053, Decrypted Result: 2344
#
# Node 4101, Decrypted Result: 46Node 4114, Decrypted Result: 810
#
# Node 4110, Decrypted Result: 240
# Node 4110, Decrypted Result: 671
# Node 4110, Decrypted Result: 4
# Node 19, Decrypted Result: 4673
# Node 4114, Decrypted Result: 238
# Node 4110, Decrypted Result: 727
# Node 2053, Decrypted Result: 2896
# Node 2069, Decrypted Result: 2755Node 15, Decrypted Result: 4792
#
# Node 17, Decrypted Result: 4452Node 24, Decrypted Result: 4218
#
# Node 2055, Decrypted Result: 2247
# Node 2053, Decrypted Result: 2851
# Node 19, Decrypted Result: 4482
# Node 23, Decrypted Result: 4490
# Node 2069, Decrypted Result: 2524Node 2053, Decrypted Result: 2094
#
# Node 15, Decrypted Result: 4335
# Node 2055, Decrypted Result: 2342
# Node 19, Decrypted Result: 4333
# Node 23, Decrypted Result: 4801
# Node 19, Decrypted Result: 4905
# Node 15, Decrypted Result: 4822
# Node 4114, Decrypted Result: 355Node 8, Decrypted Result: 4294
# Node 2073, Decrypted Result: 2169
# Node 17, Decrypted Result: 4790
# Node 15, Decrypted Result: 4766
#
# Node 2055, Decrypted Result: 2894
# Node 2069, Decrypted Result: 2623Node 2055, Decrypted Result: 2849Node 15, Decrypted Result: 4099
#
#
# Node 2055, Decrypted Result: 2092
# Node 2069, Decrypted Result: 2432
# Node 24, Decrypted Result: 4489
# Node 23, Decrypted Result: 4570
# Node 17, Decrypted Result: 4333
# Node 8, Decrypted Result: 4389
# Node 24, Decrypted Result: 4800Node 2069, Decrypted Result: 2283
#
# Node 4110, Decrypted Result: 192
# Node 19, Decrypted Result: 4450Node 17, Decrypted Result: 4764
#
# Node 2069, Decrypted Result: 2855Node 4114, Decrypted Result: 693Node 2075, Decrypted Result: 2167
#
#
# Node 17, Decrypted Result: 4820Node 8, Decrypted Result: 4896
#
# Node 8, Decrypted Result: 4941
# Node 8, Decrypted Result: 4139
# Node 17, Decrypted Result: 4097Node 23, Decrypted Result: 4669
#
# Node 24, Decrypted Result: 4569
# Node 23, Decrypted Result: 4478
# Node 2073, Decrypted Result: 2440
# Node 4114, Decrypted Result: 236
# Node 2069, Decrypted Result: 2400Node 4114, Decrypted Result: 667Node 15, Decrypted Result: 4287
#
#
# Node 4110, Decrypted Result: 287
# Node 4114, Decrypted Result: 723
# Node 23, Decrypted Result: 4901Node 19, Decrypted Result: 4788Node 2085, Decrypted Result: 2157
#
#
# Node 2073, Decrypted Result: 2751Node 23, Decrypted Result: 4329
#
# Node 4110, Decrypted Result: 794
# Node 4110, Decrypted Result: 37
# Node 24, Decrypted Result: 4668
# Node 4110, Decrypted Result: 839
# Node 4114, Decrypted Result: 0
#
# Number 4114 found at iteration 11.
# Node 2073, Decrypted Result: 2520
# Node 17, Decrypted Result: 4285
# Node 23, Decrypted Result: 4446Node 19, Decrypted Result: 4762
#
# Node 24, Decrypted Result: 4477
# Node 19, Decrypted Result: 4331
# Node 19, Decrypted Result: 4818
# Node 15, Decrypted Result: 4382Node 2075, Decrypted Result: 2749Node 24, Decrypted Result: 4328
#
#
# Node 2069, Decrypted Result: 2738Node 24, Decrypted Result: 4900
# Node 15, Decrypted Result: 4132
# Node 2073, Decrypted Result: 2619
#
# Node 38, Decrypted Result: 4204
# Node 2075, Decrypted Result: 2438
# Node 2075, Decrypted Result: 2518
# Node 15, Decrypted Result: 4934
# Node 4114, Decrypted Result: 188
# Node 2069, Decrypted Result: 2712
# Node 24, Decrypted Result: 4445Node 15, Decrypted Result: 4889
#
# Node 2073, Decrypted Result: 2428
# Node 2069, Decrypted Result: 2768
# Node 2069, Decrypted Result: 2281
# Node 2073, Decrypted Result: 2279
# Node 2075, Decrypted Result: 2617
# Node 2073, Decrypted Result: 2851
# Node 23, Decrypted Result: 4784Node 2085, Decrypted Result: 2739
#
# Node 2085, Decrypted Result: 2508
# Node 17, Decrypted Result: 4380
# Node 17, Decrypted Result: 4130
# Node 23, Decrypted Result: 4758
# Node 19, Decrypted Result: 4283
# Node 17, Decrypted Result: 4932Node 2073, Decrypted Result: 2396
#
# Node 17, Decrypted Result: 4887Node 2085, Decrypted Result: 2428
#
# Node 23, Decrypted Result: 4814
# Node 4136, Decrypted Result: 106
# Node 2075, Decrypted Result: 2277Node 2085, Decrypted Result: 2607Node 2075, Decrypted Result: 2849
#
#
# Node 2075, Decrypted Result: 2426
# Node 23, Decrypted Result: 4327
# Node 38, Decrypted Result: 4786
# Node 24, Decrypted Result: 4783
# Node 38, Decrypted Result: 4555
# Node 4114, Decrypted Result: 33
# Node 4114, Decrypted Result: 283
# Node 24, Decrypted Result: 4757
# Node 2069, Decrypted Result: 2233
# Node 2075, Decrypted Result: 2394
# Node 4114, Decrypted Result: 790
# Node 4114, Decrypted Result: 835
# Node 24, Decrypted Result: 4813
# Node 2085, Decrypted Result: 2839Node 38, Decrypted Result: 4654
#
# Node 2085, Decrypted Result: 2267Node 38, Decrypted Result: 4475
#
# Node 2090, Decrypted Result: 2152Node 2085, Decrypted Result: 2416
#
# Node 4136, Decrypted Result: 688
# Node 24, Decrypted Result: 4326
# Node 19, Decrypted Result: 4378Node 2073, Decrypted Result: 2734
#
# Node 4136, Decrypted Result: 457
# Node 23, Decrypted Result: 4279Node 19, Decrypted Result: 4128
#
# Node 2073, Decrypted Result: 2708
# Node 19, Decrypted Result: 4885Node 2085, Decrypted Result: 2384
#
# Node 4136, Decrypted Result: 556Node 38, Decrypted Result: 4886Node 2073, Decrypted Result: 2764
#
#
# Node 38, Decrypted Result: 4314
# Node 19, Decrypted Result: 4930Node 4136, Decrypted Result: 377
#
# Node 2090, Decrypted Result: 2734Node 38, Decrypted Result: 4463Node 4139, Decrypted Result: 103
#
#
# Node 2090, Decrypted Result: 2503Node 24, Decrypted Result: 4278
#
# Node 2075, Decrypted Result: 2732
# Node 2075, Decrypted Result: 2706Node 2073, Decrypted Result: 2277
#
# Node 2069, Decrypted Result: 2328Node 2090, Decrypted Result: 2602Node 2069, Decrypted Result: 2835Node 2075, Decrypted Result: 2762Node 38, Decrypted Result: 4431Node 4136, Decrypted Result: 788
#
#
#
#
#
# Node 2069, Decrypted Result: 2078
# Node 4136, Decrypted Result: 216
# Node 4139, Decrypted Result: 685
# Node 2090, Decrypted Result: 2423Node 2069, Decrypted Result: 2880
#
# Node 4136, Decrypted Result: 365Node 47, Decrypted Result: 4195
#
# Node 2085, Decrypted Result: 2696
# Node 2085, Decrypted Result: 2722
# Node 2073, Decrypted Result: 2229
# Node 4136, Decrypted Result: 333Node 2085, Decrypted Result: 2752Node 4139, Decrypted Result: 553Node 23, Decrypted Result: 4881Node 23, Decrypted Result: 4124Node 2075, Decrypted Result: 2275
#
#
#
#
#
# Node 23, Decrypted Result: 4374
# Node 4139, Decrypted Result: 454
# Node 2090, Decrypted Result: 2262
# Node 47, Decrypted Result: 4777
# Node 2090, Decrypted Result: 2834
# Node 4139, Decrypted Result: 374Node 38, Decrypted Result: 4743Node 23, Decrypted Result: 4926Node 47, Decrypted Result: 4645
#
# Node 24, Decrypted Result: 4880
#
# Node 24, Decrypted Result: 4123
#
# Node 38, Decrypted Result: 4799Node 2090, Decrypted Result: 2379Node 47, Decrypted Result: 4546Node 24, Decrypted Result: 4373
#
#
#
# Node 38, Decrypted Result: 4769Node 2096, Decrypted Result: 2146Node 2090, Decrypted Result: 2411
#
#
# Node 2085, Decrypted Result: 2265
# Node 2075, Decrypted Result: 2227
# Node 4139, Decrypted Result: 213
# Node 2096, Decrypted Result: 2497Node 2073, Decrypted Result: 2831Node 4136, Decrypted Result: 645Node 2073, Decrypted Result: 2324Node 4139, Decrypted Result: 330Node 2096, Decrypted Result: 2728Node 2073, Decrypted Result: 2074
#
#
#
#
#
#
# Node 47, Decrypted Result: 4466
# Node 24, Decrypted Result: 4925
# Node 2099, Decrypted Result: 2143Node 4136, Decrypted Result: 671Node 4139, Decrypted Result: 362
#
#
# Node 4139, Decrypted Result: 785
# Node 38, Decrypted Result: 4312
# Node 2096, Decrypted Result: 2596
# Node 4136, Decrypted Result: 701
# Node 2085, Decrypted Result: 2217
# Node 47, Decrypted Result: 4305
# Node 2075, Decrypted Result: 2072Node 2090, Decrypted Result: 2691Node 2075, Decrypted Result: 2829
#
#
# Node 47, Decrypted Result: 4422
# Node 2099, Decrypted Result: 2494Node 2099, Decrypted Result: 2725
#
# Node 2096, Decrypted Result: 2417
# Node 2075, Decrypted Result: 2322
# Node 2073, Decrypted Result: 2876
# Node 4136, Decrypted Result: 214Node 2090, Decrypted Result: 2717Node 52, Decrypted Result: 4190
#
#
# Node 47, Decrypted Result: 4454
# Node 2090, Decrypted Result: 2747
# Node 38, Decrypted Result: 4264
# Node 2099, Decrypted Result: 2593
# Node 2096, Decrypted Result: 2256
# Node 2096, Decrypted Result: 2373Node 4139, Decrypted Result: 642Node 2085, Decrypted Result: 2062
#
#
# Node 47, Decrypted Result: 4877
# Node 52, Decrypted Result: 4772Node 52, Decrypted Result: 4541
#
# Node 2085, Decrypted Result: 2819
# Node 2099, Decrypted Result: 2414
# Node 2085, Decrypted Result: 2312
# Node 4139, Decrypted Result: 698
# Node 2075, Decrypted Result: 2874
# Node 2090, Decrypted Result: 2260
# Node 4136, Decrypted Result: 166
# Node 4139, Decrypted Result: 668Node 2100, Decrypted Result: 2142
#
# Node 2099, Decrypted Result: 2370Node 47, Decrypted Result: 4734Node 38, Decrypted Result: 4109Node 2099, Decrypted Result: 2253
#
#
#
# Node 2100, Decrypted Result: 2724Node 2100, Decrypted Result: 2493
#
# Node 52, Decrypted Result: 4640
# Node 2096, Decrypted Result: 2405
# Node 2096, Decrypted Result: 2828
# Node 47, Decrypted Result: 4790
# Node 38, Decrypted Result: 4359Node 38, Decrypted Result: 4866
#
# Node 52, Decrypted Result: 4461
# Node 2090, Decrypted Result: 2212
# Node 2085, Decrypted Result: 2864
# Node 4139, Decrypted Result: 211
# Node 52, Decrypted Result: 4417Node 2096, Decrypted Result: 2685Node 4136, Decrypted Result: 11Node 54, Decrypted Result: 4770Node 52, Decrypted Result: 4300
#
#
#
#
# Node 47, Decrypted Result: 4760Node 54, Decrypted Result: 4188
#
# Node 2100, Decrypted Result: 2592
# Node 54, Decrypted Result: 4539
# Node 2096, Decrypted Result: 2741
# Node 4136, Decrypted Result: 261Node 2099, Decrypted Result: 2402
#
# Node 4139, Decrypted Result: 163
# Node 2100, Decrypted Result: 2413
# Node 4136, Decrypted Result: 768
# Node 2099, Decrypted Result: 2825
# Node 47, Decrypted Result: 4303Node 38, Decrypted Result: 4911
#
# Node 2100, Decrypted Result: 2369Node 2090, Decrypted Result: 2057Node 2099, Decrypted Result: 2682
#
#
# Node 2102, Decrypted Result: 2722Node 2100, Decrypted Result: 2252
#
# Node 2096, Decrypted Result: 2711Node 2102, Decrypted Result: 2140
#
# Node 2102, Decrypted Result: 2491
# Node 2099, Decrypted Result: 2738
# Node 54, Decrypted Result: 4638Node 2090, Decrypted Result: 2307
#
# Node 47, Decrypted Result: 4255
# Node 4139, Decrypted Result: 8Node 54, Decrypted Result: 4415Node 52, Decrypted Result: 4729Node 54, Decrypted Result: 4459Node 2096, Decrypted Result: 2254Node 4136, Decrypted Result: 813Node 52, Decrypted Result: 4449
#
#
#
#
#
#
# Node 54, Decrypted Result: 4298Node 2105, Decrypted Result: 2719Node 2090, Decrypted Result: 2814
#
#
# Node 52, Decrypted Result: 4872
# Node 52, Decrypted Result: 4785
# Node 4139, Decrypted Result: 258Node 2099, Decrypted Result: 2708Node 2105, Decrypted Result: 2137
#
#
# Node 2096, Decrypted Result: 2206Node 2102, Decrypted Result: 2590
#
# Node 2102, Decrypted Result: 2367Node 2100, Decrypted Result: 2681Node 47, Decrypted Result: 4100
#
#
# Node 2099, Decrypted Result: 2251
# Node 2090, Decrypted Result: 2859
# Node 2102, Decrypted Result: 2411
# Node 2105, Decrypted Result: 2488
# Node 2106, Decrypted Result: 2718Node 2102, Decrypted Result: 2250
#
# Node 2100, Decrypted Result: 2401
# Node 4139, Decrypted Result: 765
# Node 2100, Decrypted Result: 2737
# Node 2096, Decrypted Result: 2051Node 2105, Decrypted Result: 2364Node 2099, Decrypted Result: 2203Node 52, Decrypted Result: 4755
#
# Node 54, Decrypted Result: 4727
#
#
# Node 2100, Decrypted Result: 2824
# Node 2105, Decrypted Result: 2408Node 52, Decrypted Result: 4298Node 2106, Decrypted Result: 2487
#
#
# Node 4139, Decrypted Result: 810
# Node 2105, Decrypted Result: 2587
# Node 2105, Decrypted Result: 2247Node 59, Decrypted Result: 4765
#
# Node 47, Decrypted Result: 4350
# Node 2106, Decrypted Result: 2136
# Node 54, Decrypted Result: 4447
# Node 2102, Decrypted Result: 2679Node 2099, Decrypted Result: 2048Node 52, Decrypted Result: 4250Node 47, Decrypted Result: 4857Node 2106, Decrypted Result: 2363
#
#
#
#
# Node 59, Decrypted Result: 4534
# Node 54, Decrypted Result: 4783
# Node 2100, Decrypted Result: 2707
# Node 2106, Decrypted Result: 2407Node 2100, Decrypted Result: 2250Node 47, Decrypted Result: 4902
#
#
# Node 4157, Decrypted Result: 667Node 2096, Decrypted Result: 2301Node 2106, Decrypted Result: 2246
#
#
# Node 2106, Decrypted Result: 2586
# Node 54, Decrypted Result: 4870
# Node 59, Decrypted Result: 4410Node 2105, Decrypted Result: 2676Node 52, Decrypted Result: 4095
#
#
# Node 59, Decrypted Result: 4183
# Node 2100, Decrypted Result: 2202Node 4157, Decrypted Result: 436
#
# Node 2102, Decrypted Result: 2399
# Node 2096, Decrypted Result: 2808
# Node 59, Decrypted Result: 4454Node 54, Decrypted Result: 4296Node 2096, Decrypted Result: 2853Node 2102, Decrypted Result: 2735
#
#
#
# Node 66, Decrypted Result: 4758Node 59, Decrypted Result: 4293Node 2099, Decrypted Result: 2298
#
#
# Node 54, Decrypted Result: 4753
# Node 59, Decrypted Result: 4633
# Node 2106, Decrypted Result: 2675Node 4157, Decrypted Result: 312Node 2100, Decrypted Result: 2047
#
#
# Node 54, Decrypted Result: 4248
# Node 4157, Decrypted Result: 85
# Node 66, Decrypted Result: 4527
# Node 2116, Decrypted Result: 2708Node 4157, Decrypted Result: 195Node 2102, Decrypted Result: 2822Node 52, Decrypted Result: 4345
#
#
#
# Node 2105, Decrypted Result: 2732Node 2105, Decrypted Result: 2396
#
# Node 2102, Decrypted Result: 2248Node 4157, Decrypted Result: 356Node 2099, Decrypted Result: 2850Node 2099, Decrypted Result: 2805
#
#
#
# Node 54, Decrypted Result: 4093Node 66, Decrypted Result: 4403Node 59, Decrypted Result: 4722
#
#
# Node 2102, Decrypted Result: 2705
# Node 4157, Decrypted Result: 535
# Node 2102, Decrypted Result: 2200
# Node 4165, Decrypted Result: 659Node 2116, Decrypted Result: 2477Node 2100, Decrypted Result: 2297Node 66, Decrypted Result: 4286Node 66, Decrypted Result: 4176
#
#
#
#
# Node 66, Decrypted Result: 4447Node 52, Decrypted Result: 4897Node 2105, Decrypted Result: 2245Node 2106, Decrypted Result: 2731
#
#
#
# Node 2105, Decrypted Result: 2819
# Node 2116, Decrypted Result: 2353Node 2102, Decrypted Result: 2045Node 4157, Decrypted Result: 624
#
#
# Node 52, Decrypted Result: 4852
# Node 2106, Decrypted Result: 2395
# Node 2105, Decrypted Result: 2197Node 2116, Decrypted Result: 2236Node 2105, Decrypted Result: 2702
#
#
# Node 66, Decrypted Result: 4626
# Node 2106, Decrypted Result: 2818Node 66, Decrypted Result: 4715Node 4165, Decrypted Result: 304
# Node 59, Decrypted Result: 4778
#
#
# Node 2105, Decrypted Result: 2042
# Node 2116, Decrypted Result: 2397Node 2106, Decrypted Result: 2244Node 2118, Decrypted Result: 2706
# Node 2100, Decrypted Result: 2849
#
#
# Node 2116, Decrypted Result: 2126
# Node 4165, Decrypted Result: 428
# Node 54, Decrypted Result: 4343
# Node 2106, Decrypted Result: 2196Node 4165, Decrypted Result: 187
#
# Node 59, Decrypted Result: 4442
# Node 2106, Decrypted Result: 2701Node 2116, Decrypted Result: 2576
#
# Node 2118, Decrypted Result: 2351Node 59, Decrypted Result: 4865Node 2116, Decrypted Result: 2665Node 4157, Decrypted Result: 680Node 2106, Decrypted Result: 2041
#
#
#
#
# Node 59, Decrypted Result: 4291Node 54, Decrypted Result: 4895
#
# Node 2118, Decrypted Result: 2475Node 2100, Decrypted Result: 2804
# Node 4166, Decrypted Result: 658
# Node 4165, Decrypted Result: 348
#
# Node 4165, Decrypted Result: 77
# Node 2102, Decrypted Result: 2295
# Node 4165, Decrypted Result: 616Node 4166, Decrypted Result: 303Node 4157, Decrypted Result: 767Node 59, Decrypted Result: 4088
#
#
#
# Node 59, Decrypted Result: 4243Node 2118, Decrypted Result: 2234
#
# Node 66, Decrypted Result: 4771Node 4165, Decrypted Result: 527Node 59, Decrypted Result: 4748Node 4157, Decrypted Result: 344
#
#
#
# Node 4166, Decrypted Result: 427Node 2102, Decrypted Result: 2847Node 4157, Decrypted Result: 193
#
#
# Node 71, Decrypted Result: 4753Node 2118, Decrypted Result: 2395
#
# Node 54, Decrypted Result: 4850
# Node 2118, Decrypted Result: 2124
# Node 71, Decrypted Result: 4398Node 4157, Decrypted Result: -10Node 4157, Decrypted Result: 145Node 2105, Decrypted Result: 2292Node 4166, Decrypted Result: 186
#
#
#
#
# Number 4147 NOT found after 33 comparisons.
#
# Node 66, Decrypted Result: 4858Node 2118, Decrypted Result: 2663
#
# Node 71, Decrypted Result: 4522
# Node 66, Decrypted Result: 4284Node 4166, Decrypted Result: 347Node 75, Decrypted Result: 4749Node 2118, Decrypted Result: 2574Node 66, Decrypted Result: 4435Node 2105, Decrypted Result: 2844
#
# Node 2116, Decrypted Result: 2721
#
#
#
#
# Node 2102, Decrypted Result: 2802Node 4157, Decrypted Result: 650
#
# Node 2106, Decrypted Result: 2291Node 66, Decrypted Result: 4236Node 71, Decrypted Result: 4281
#
#
# Node 75, Decrypted Result: 4394Node 4166, Decrypted Result: 76
#
# Node 2116, Decrypted Result: 2808Node 4166, Decrypted Result: 615
#
# Node 2106, Decrypted Result: 2843Node 71, Decrypted Result: 4442Node 76, Decrypted Result: 4748Node 2116, Decrypted Result: 2234
#
#
#
# Node 4166, Decrypted Result: 526Node 4165, Decrypted Result: 672
#
# Node 75, Decrypted Result: 4518
# Node 2116, Decrypted Result: 2385
# Node 76, Decrypted Result: 4393
# Node 2116, Decrypted Result: 2186Node 75, Decrypted Result: 4277
#
# Node 2105, Decrypted Result: 2799Node 71, Decrypted Result: 4171Node 66, Decrypted Result: 4741
# Node 59, Decrypted Result: 4338
#
#
# Node 71, Decrypted Result: 4710
# Node 4165, Decrypted Result: 759
# Node 71, Decrypted Result: 4621Node 2118, Decrypted Result: 2719Node 75, Decrypted Result: 4438Node 59, Decrypted Result: 4890Node 4165, Decrypted Result: 185Node 80, Decrypted Result: 4744
#
#
#
#
#
# Node 4165, Decrypted Result: 137Node 76, Decrypted Result: 4276
#
# Node 76, Decrypted Result: 4517
# Node 80, Decrypted Result: 4389
# Node 4157, Decrypted Result: 240Node 4165, Decrypted Result: 336Node 2106, Decrypted Result: 2798Node 75, Decrypted Result: 4167Node 2116, Decrypted Result: 2691
#
#
#
#
# Node 75, Decrypted Result: 4706
# Node 80, Decrypted Result: 4272Node 4166, Decrypted Result: 671Node 80, Decrypted Result: 4513Node 2118, Decrypted Result: 2184
#
#
#
# Node 2118, Decrypted Result: 2806Node 85, Decrypted Result: 4384
#
# Node 2118, Decrypted Result: 2232Node 85, Decrypted Result: 4739
#
# Node 4157, Decrypted Result: 792
# Node 75, Decrypted Result: 4617
# Node 76, Decrypted Result: 4437
# Node 76, Decrypted Result: 4705
# Node 2118, Decrypted Result: 2383Node 59, Decrypted Result: 4845Node 4165, Decrypted Result: 642Node 76, Decrypted Result: 4166
#
#
#
# Node 66, Decrypted Result: 4331
# Node 85, Decrypted Result: 4508Node 4166, Decrypted Result: 136Node 4181, Decrypted Result: 288Node 85, Decrypted Result: 4267Node 4166, Decrypted Result: 758
#
#
#
#
# Node 71, Decrypted Result: 4766Node 4166, Decrypted Result: 184Node 4181, Decrypted Result: 643
#
#
# Node 80, Decrypted Result: 4701Node 66, Decrypted Result: 4883
#
# Node 80, Decrypted Result: 4433Node 76, Decrypted Result: 4616
#
# Node 4157, Decrypted Result: 747Node 2118, Decrypted Result: 2689Node 4166, Decrypted Result: 335Node 80, Decrypted Result: 4162
#
#
#
# Node 2116, Decrypted Result: 2281
# Node 71, Decrypted Result: 4853Node 2134, Decrypted Result: 2335
#
# Node 4181, Decrypted Result: 412Node 71, Decrypted Result: 4231Node 4181, Decrypted Result: 171
#
#
# Node 85, Decrypted Result: 4696
# Node 2134, Decrypted Result: 2690Node 2116, Decrypted Result: 2833
#
# Node 75, Decrypted Result: 4762
# Node 71, Decrypted Result: 4279
# Node 85, Decrypted Result: 4428
# Node 80, Decrypted Result: 4612Node 4165, Decrypted Result: 232
#
# Node 85, Decrypted Result: 4157Node 66, Decrypted Result: 4838Node 4166, Decrypted Result: 641
#
#
# Node 71, Decrypted Result: 4430
# Node 75, Decrypted Result: 4849Node 86, Decrypted Result: 4383
#
# Node 2134, Decrypted Result: 2459Node 2134, Decrypted Result: 2218
#
# Node 75, Decrypted Result: 4227
# Node 4181, Decrypted Result: 600
# Node 4165, Decrypted Result: 784
# Node 75, Decrypted Result: 4275Node 4181, Decrypted Result: 332Node 86, Decrypted Result: 4738Node 85, Decrypted Result: 4607
#
#
#
# Node 76, Decrypted Result: 4761
# Node 2137, Decrypted Result: 2332
# Node 76, Decrypted Result: 4848
# Node 2118, Decrypted Result: 2279Node 76, Decrypted Result: 4226Node 2116, Decrypted Result: 2788Node 86, Decrypted Result: 4266Node 86, Decrypted Result: 4507Node 4181, Decrypted Result: 61Node 75, Decrypted Result: 4426Node 71, Decrypted Result: 4736
#
#
#
#
#
#
#
# Node 2134, Decrypted Result: 2647
# Node 4181, Decrypted Result: 511
# Node 2118, Decrypted Result: 2831
# Node 76, Decrypted Result: 4274Node 2134, Decrypted Result: 2379Node 2137, Decrypted Result: 2687
#
#
# Node 80, Decrypted Result: 4757
# Node 4182, Decrypted Result: 287
# Node 2137, Decrypted Result: 2456Node 80, Decrypted Result: 4222Node 4166, Decrypted Result: 231Node 2137, Decrypted Result: 2215
#
#
#
# Node 80, Decrypted Result: 4844
# Node 2134, Decrypted Result: 2108Node 76, Decrypted Result: 4425Node 4165, Decrypted Result: 739Node 75, Decrypted Result: 4732
#
#
#
# Node 86, Decrypted Result: 4695
# Node 2134, Decrypted Result: 2558
# Node 2136, Decrypted Result: 2333Node 80, Decrypted Result: 4270Node 86, Decrypted Result: 4427Node 4166, Decrypted Result: 783
#
#
#
# Node 85, Decrypted Result: 4752
# Node 4182, Decrypted Result: 411Node 85, Decrypted Result: 4217Node 71, Decrypted Result: 4326Node 4182, Decrypted Result: 170
#
#
#
# Node 85, Decrypted Result: 4839
# Node 4182, Decrypted Result: 642
# Node 2137, Decrypted Result: 2644
# Node 2118, Decrypted Result: 2786Node 80, Decrypted Result: 4421Node 86, Decrypted Result: 4156
#
#
# Node 86, Decrypted Result: 4606
# Node 76, Decrypted Result: 4731
# Node 88, Decrypted Result: 4381Node 4181, Decrypted Result: 743
#
# Node 2137, Decrypted Result: 2376Node 71, Decrypted Result: 4878Node 85, Decrypted Result: 4265
#
#
# Node 75, Decrypted Result: 4322Node 2136, Decrypted Result: 2457Node 2136, Decrypted Result: 2216
#
#
# Node 4182, Decrypted Result: 599
# Node 4181, Decrypted Result: 656
# Node 4181, Decrypted Result: 121
# Node 2136, Decrypted Result: 2688
# Node 2137, Decrypted Result: 2555
# Node 85, Decrypted Result: 4416Node 2137, Decrypted Result: 2105Node 4166, Decrypted Result: 738
#
#
# Node 2134, Decrypted Result: 2790Node 2143, Decrypted Result: 2326
#
# Node 88, Decrypted Result: 4505Node 76, Decrypted Result: 4321Node 88, Decrypted Result: 4264Node 80, Decrypted Result: 4727
#
#
#
# Node 2136, Decrypted Result: 2645
# Node 4182, Decrypted Result: 331Node 75, Decrypted Result: 4874Node 4181, Decrypted Result: 169
#
#
# Node 2134, Decrypted Result: 2703
# Node 4182, Decrypted Result: 510
# Node 2134, Decrypted Result: 2168
# Node 4192, Decrypted Result: 277Node 86, Decrypted Result: 4838
#
# Node 88, Decrypted Result: 4736
# Node 80, Decrypted Result: 4317Node 2143, Decrypted Result: 2209Node 4181, Decrypted Result: 320Node 2143, Decrypted Result: 2450Node 71, Decrypted Result: 4833
#
#
#
#
# Node 88, Decrypted Result: 4693
# Node 85, Decrypted Result: 4722
# Node 2136, Decrypted Result: 2377Node 2134, Decrypted Result: 2216Node 76, Decrypted Result: 4873
#
#
# Node 4182, Decrypted Result: 60
# Node 2136, Decrypted Result: 2556
# Node 86, Decrypted Result: 4216Node 86, Decrypted Result: 4751
#
# Node 2145, Decrypted Result: 2324Node 2137, Decrypted Result: 2787
#
# Node 85, Decrypted Result: 4312Node 4192, Decrypted Result: 401Node 4192, Decrypted Result: 160
#
#
# Node 2143, Decrypted Result: 2638
# Node 75, Decrypted Result: 4829Node 2134, Decrypted Result: 2367
#
# Node 2143, Decrypted Result: 2681
# Node 4181, Decrypted Result: 626
# Node 88, Decrypted Result: 4604Node 86, Decrypted Result: 4264Node 88, Decrypted Result: 4425
# Node 80, Decrypted Result: 4869
#
#
# Node 2137, Decrypted Result: 2165
# Node 2137, Decrypted Result: 2700
# Node 4182, Decrypted Result: 742
# Node 2136, Decrypted Result: 2106
# Node 4192, Decrypted Result: 589Node 2145, Decrypted Result: 2448
# Node 2145, Decrypted Result: 2207
#
# Node 4181, Decrypted Result: 216
# Node 4194, Decrypted Result: 275
# Node 2143, Decrypted Result: 2549
# Node 86, Decrypted Result: 4415Node 76, Decrypted Result: 4828
#
# Node 2137, Decrypted Result: 2213Node 85, Decrypted Result: 4864Node 2143, Decrypted Result: 2370
#
# Node 2134, Decrypted Result: 2673
#
# Node 4192, Decrypted Result: 632
# Node 4182, Decrypted Result: 120Node 4182, Decrypted Result: 655
#
# Node 2136, Decrypted Result: 2788
# Node 2145, Decrypted Result: 2636
# Node 4194, Decrypted Result: 399Node 2134, Decrypted Result: 2263Node 4194, Decrypted Result: 158
#
#
# Node 4192, Decrypted Result: 500
# Node 88, Decrypted Result: 4154Node 2147, Decrypted Result: 2322
#
# Node 80, Decrypted Result: 4824Node 2137, Decrypted Result: 2364Node 86, Decrypted Result: 4721Node 4181, Decrypted Result: 768Node 4192, Decrypted Result: 321Node 4182, Decrypted Result: 168
#
#
#
#
#
# Node 88, Decrypted Result: 4836
# Node 4194, Decrypted Result: 587Node 2136, Decrypted Result: 2166
#
# Node 2145, Decrypted Result: 2679Node 2136, Decrypted Result: 2701
#
# Node 2147, Decrypted Result: 2205Node 2147, Decrypted Result: 2446Node 86, Decrypted Result: 4311
#
#
# Node 2145, Decrypted Result: 2547
# Node 2143, Decrypted Result: 2781
# Node 2148, Decrypted Result: 2321Node 2136, Decrypted Result: 2214Node 2145, Decrypted Result: 2368Node 2134, Decrypted Result: 2815
# Node 2147, Decrypted Result: 2634
#
#
#
# Node 88, Decrypted Result: 4214Node 4182, Decrypted Result: 319Node 2137, Decrypted Result: 2670
# Node 85, Decrypted Result: 4819
#
#
# Node 2143, Decrypted Result: 2099
# Node 2137, Decrypted Result: 2260Node 88, Decrypted Result: 4749
#
# Node 2148, Decrypted Result: 2445
# Node 4194, Decrypted Result: 498
# Node 4194, Decrypted Result: 630
# Node 2148, Decrypted Result: 2204
# Node 4192, Decrypted Result: 732
# Node 2149, Decrypted Result: 2320Node 2148, Decrypted Result: 2633Node 2143, Decrypted Result: 2159
#
#
# Node 4194, Decrypted Result: 319Node 86, Decrypted Result: 4863Node 88, Decrypted Result: 4262
#
#
# Node 4182, Decrypted Result: 625Node 4181, Decrypted Result: 723
#
# Node 4192, Decrypted Result: 50
# Node 4182, Decrypted Result: 215
# Node 2147, Decrypted Result: 2545
# Node 2143, Decrypted Result: 2694
# Node 2149, Decrypted Result: 2444Node 2136, Decrypted Result: 2365
#
# Node 2147, Decrypted Result: 2677
# Node 100, Decrypted Result: 4369Node 2149, Decrypted Result: 2632
#
# Node 2149, Decrypted Result: 2203
# Node 2145, Decrypted Result: 2779
# Node 4192, Decrypted Result: 110
# Node 2136, Decrypted Result: 2671Node 2134, Decrypted Result: 2770
#
# Node 2143, Decrypted Result: 2207Node 2147, Decrypted Result: 2366Node 2137, Decrypted Result: 2812
#
#
# Node 2148, Decrypted Result: 2544Node 2136, Decrypted Result: 2261
#
# Node 4192, Decrypted Result: 645
# Node 100, Decrypted Result: 4493Node 2145, Decrypted Result: 2097
#
# Node 2152, Decrypted Result: 2317Node 100, Decrypted Result: 4681
#
# Node 88, Decrypted Result: 4413
# Node 4194, Decrypted Result: 730Node 2148, Decrypted Result: 2676
#
# Node 2145, Decrypted Result: 2157
# Node 88, Decrypted Result: 4719Node 100, Decrypted Result: 4252Node 86, Decrypted Result: 4818Node 88, Decrypted Result: 4309
#
#
#
# Node 2149, Decrypted Result: 2543
# Node 2148, Decrypted Result: 2365Node 4182, Decrypted Result: 767Node 4192, Decrypted Result: 158
#
#
# Node 2152, Decrypted Result: 2441Node 2145, Decrypted Result: 2692
#
# Node 4201, Decrypted Result: 268Node 2152, Decrypted Result: 2629
#
# Node 2147, Decrypted Result: 2777
# Node 4194, Decrypted Result: 48
# Node 2149, Decrypted Result: 2675Node 4194, Decrypted Result: 108Node 2143, Decrypted Result: 2358
#
#
# Node 100, Decrypted Result: 4592
# Node 2143, Decrypted Result: 2254
# Node 2136, Decrypted Result: 2813Node 2145, Decrypted Result: 2205Node 2149, Decrypted Result: 2364
#
#
# Node 2143, Decrypted Result: 2664Node 2137, Decrypted Result: 2767
#
# Node 2152, Decrypted Result: 2200
# Node 106, Decrypted Result: 4363Node 4201, Decrypted Result: 580
#
# Node 4194, Decrypted Result: 643
# Node 4201, Decrypted Result: 392
# Node 2147, Decrypted Result: 2155
# Node 100, Decrypted Result: 4724
# Node 2152, Decrypted Result: 2540Node 2147, Decrypted Result: 2095
#
# Node 4192, Decrypted Result: 205Node 2148, Decrypted Result: 2776Node 4192, Decrypted Result: 309
#
#
# Node 4194, Decrypted Result: 156Node 100, Decrypted Result: 4413Node 88, Decrypted Result: 4861
#
#
# Node 4192, Decrypted Result: 615Node 4182, Decrypted Result: 722
#
# Node 4203, Decrypted Result: 266Node 106, Decrypted Result: 4675
#
# Node 4201, Decrypted Result: 151
# Node 106, Decrypted Result: 4487Node 2147, Decrypted Result: 2690Node 4201, Decrypted Result: 491Node 2148, Decrypted Result: 2154
#
#
# Node 2152, Decrypted Result: 2672
#
# Node 2145, Decrypted Result: 2252
# Node 2148, Decrypted Result: 2094
# Node 2145, Decrypted Result: 2356Node 2149, Decrypted Result: 2775
#
# Node 2152, Decrypted Result: 2361Node 4203, Decrypted Result: 578Node 4205, Decrypted Result: 264Node 2147, Decrypted Result: 2203Node 2143, Decrypted Result: 2806
#
#
#
#
# Node 106, Decrypted Result: 4246
# Node 2145, Decrypted Result: 2662Node 2136, Decrypted Result: 2768
#
# Node 106, Decrypted Result: 4586
# Node 4201, Decrypted Result: 623Node 4203, Decrypted Result: 390Node 2149, Decrypted Result: 2153
#
#
# Node 2148, Decrypted Result: 2689
# Node 4194, Decrypted Result: 203
# Node 4205, Decrypted Result: 576
# Node 4192, Decrypted Result: 757Node 2148, Decrypted Result: 2202Node 4201, Decrypted Result: 312
#
#
# Node 2149, Decrypted Result: 2093
# Node 4194, Decrypted Result: 307Node 110, Decrypted Result: 4359
#
# Node 4203, Decrypted Result: 489
# Node 88, Decrypted Result: 4816Node 100, Decrypted Result: 4202Node 106, Decrypted Result: 4718Node 4205, Decrypted Result: 388Node 4194, Decrypted Result: 613
#
#
#
#
# Node 100, Decrypted Result: 4824
# Node 4203, Decrypted Result: 149Node 2147, Decrypted Result: 2250
#
# Node 2149, Decrypted Result: 2688
# Node 110, Decrypted Result: 4671
# Node 4207, Decrypted Result: 262Node 2149, Decrypted Result: 2201Node 106, Decrypted Result: 4407Node 2145, Decrypted Result: 2804
#
#
#
# Node 4205, Decrypted Result: 487
# Node 2143, Decrypted Result: 2761
# Node 100, Decrypted Result: 4142
# Node 4203, Decrypted Result: 621Node 2152, Decrypted Result: 2150Node 110, Decrypted Result: 4483Node 2147, Decrypted Result: 2354
#
#
#
# Node 4205, Decrypted Result: 147
# Node 2147, Decrypted Result: 2660
# Node 2152, Decrypted Result: 2772
# Node 4207, Decrypted Result: 574
# Node 2148, Decrypted Result: 2249
# Node 100, Decrypted Result: 4737
# Node 2159, Decrypted Result: 2310
# Node 4194, Decrypted Result: 755Node 4203, Decrypted Result: 310Node 100, Decrypted Result: 4250
#
#
# Node 4192, Decrypted Result: 712
# Node 4201, Decrypted Result: 101Node 4205, Decrypted Result: 619Node 110, Decrypted Result: 4242Node 4207, Decrypted Result: 386Node 2152, Decrypted Result: 2090
#
#
#
#
# Node 110, Decrypted Result: 4582
# Node 2148, Decrypted Result: 2353Node 2148, Decrypted Result: 2659
#
# Node 2159, Decrypted Result: 2622
# Node 111, Decrypted Result: 4358
# Node 2149, Decrypted Result: 2248Node 4201, Decrypted Result: 723Node 2152, Decrypted Result: 2685Node 2145, Decrypted Result: 2759
#
#
#
# Node 4205, Decrypted Result: 308Node 2152, Decrypted Result: 2198Node 2147, Decrypted Result: 2802
#
#
# Node 2159, Decrypted Result: 2434Node 110, Decrypted Result: 4714Node 106, Decrypted Result: 4196
#
#
# Node 4207, Decrypted Result: 145
# Node 4201, Decrypted Result: 41
# Node 111, Decrypted Result: 4670
# Node 2149, Decrypted Result: 2352Node 2149, Decrypted Result: 2658
#
# Node 4207, Decrypted Result: 485
# Node 4210, Decrypted Result: 259
# Node 4194, Decrypted Result: 710
# Node 2148, Decrypted Result: 2801Node 4201, Decrypted Result: 149Node 110, Decrypted Result: 4403
#
#
# Node 4201, Decrypted Result: 636
# Node 4207, Decrypted Result: 617Node 111, Decrypted Result: 4482
#
# Node 2159, Decrypted Result: 2533Node 4210, Decrypted Result: 571Node 106, Decrypted Result: 4136
#
#
# Node 100, Decrypted Result: 4297
# Node 2159, Decrypted Result: 2193
# Node 106, Decrypted Result: 4818
# ...
# Node 4774, Decrypted Result: 50
# Node 2710, Decrypted Result: 2097Node 2734, Decrypted Result: 2103
#
# Node 2779, Decrypted Result: 2145Node 2734, Decrypted Result: 2170
#
# Node 680, Decrypted Result: 4269
# Node 682, Decrypted Result: 4142
# Node 2717, Decrypted Result: 2090Node 4782, Decrypted Result: 55
#
# Node 4782, Decrypted Result: 122Node 4828, Decrypted Result: 96
#
# Node 4774, Decrypted Result: 175
# Node 2731, Decrypted Result: 2093
# Node 688, Decrypted Result: 4149Node 4763, Decrypted Result: 44
#
# Node 732, Decrypted Result: 4192Node 688, Decrypted Result: 4216
#
# Node 682, Decrypted Result: 4267
# Node 2733, Decrypted Result: 2091
# Node 4784, Decrypted Result: 120Node 735, Decrypted Result: 4189
#
# Node 2731, Decrypted Result: 2218
# Node 4784, Decrypted Result: 53
# Node 2734, Decrypted Result: 2090Node 671, Decrypted Result: 4136
#
# Node 692, Decrypted Result: 4212Node 4832, Decrypted Result: 92
#
# Node 2733, Decrypted Result: 2216
# Node 692, Decrypted Result: 4145Node 4782, Decrypted Result: 42
#
# Node 670, Decrypted Result: 4137
# Node 737, Decrypted Result: 4187
# Node 4789, Decrypted Result: 115
# Node 688, Decrypted Result: 4136Node 4789, Decrypted Result: 48
#
# Node 2734, Decrypted Result: 2215
# Node 2785, Decrypted Result: 2139
# Node 4790, Decrypted Result: 114
# Node 2725, Decrypted Result: 2082
# Node 4784, Decrypted Result: 40Node 4790, Decrypted Result: 47
#
# Node 2787, Decrypted Result: 2137Node 4791, Decrypted Result: 113Node 4782, Decrypted Result: 167
#
#
# Node 2726, Decrypted Result: 2081Node 692, Decrypted Result: 4132
#
# Node 4791, Decrypted Result: 46
# Node 688, Decrypted Result: 4261Node 4837, Decrypted Result: 87Node 2740, Decrypted Result: 2164
#
#
# Node 4789, Decrypted Result: 35
# Node 678, Decrypted Result: 4129
# Node 2740, Decrypted Result: 2097
# Node 743, Decrypted Result: 4181Node 4784, Decrypted Result: 165Node 4794, Decrypted Result: 110
#
#
# Node 4794, Decrypted Result: 43Node 680, Decrypted Result: 4127Node 4790, Decrypted Result: 34
#
#
# Node 692, Decrypted Result: 4257Node 745, Decrypted Result: 4179Node 702, Decrypted Result: 4202
#
#
# Node 4774, Decrypted Result: 33Node 702, Decrypted Result: 4135Node 4791, Decrypted Result: 33
#
#
# Node 2795, Decrypted Result: 2129Node 4789, Decrypted Result: 160Node 4799, Decrypted Result: 105
#
#
# Node 2740, Decrypted Result: 2084
# Node 4844, Decrypted Result: 80Node 4790, Decrypted Result: 159Node 4804, Decrypted Result: 100Node 682, Decrypted Result: 4125Node 4799, Decrypted Result: 38
#
#
#
#
# Node 4843, Decrypted Result: 81Node 710, Decrypted Result: 4194
#
# Node 4794, Decrypted Result: 30
# Node 4804, Decrypted Result: 33Node 4791, Decrypted Result: 158
#
# Node 2731, Decrypted Result: 2076
# Node 751, Decrypted Result: 4173Node 2740, Decrypted Result: 2209Node 4807, Decrypted Result: 97Node 702, Decrypted Result: 4122Node 710, Decrypted Result: 4127
#
#
#
#
# Node 2733, Decrypted Result: 2074
# Node 4807, Decrypted Result: 30Node 4799, Decrypted Result: 25Node 717, Decrypted Result: 4187Node 4851, Decrypted Result: 73Node 4794, Decrypted Result: 155
#
#
#
#
# Node 2734, Decrypted Result: 2073
# Node 4804, Decrypted Result: 20Node 2766, Decrypted Result: 2138Node 717, Decrypted Result: 4120Node 4853, Decrypted Result: 71
#
#
#
# Node 702, Decrypted Result: 4247
# Node 4782, Decrypted Result: 25Node 710, Decrypted Result: 4114
#
# Node 2806, Decrypted Result: 2118Node 4815, Decrypted Result: 89Node 4799, Decrypted Result: 150
#
#
# Node 2766, Decrypted Result: 2071
# Node 720, Decrypted Result: 4184Node 2807, Decrypted Result: 2117Node 4807, Decrypted Result: 17Node 688, Decrypted Result: 4119
#
#
#
# Node 4804, Decrypted Result: 145
# Node 4815, Decrypted Result: 22
# Node 2808, Decrypted Result: 2116Node 4816, Decrypted Result: 88
#
# Node 717, Decrypted Result: 4107
# Node 4784, Decrypted Result: 23
# Node 710, Decrypted Result: 4239
# Node 720, Decrypted Result: 4117
# Node 2766, Decrypted Result: 2058Node 4854, Decrypted Result: 70Node 2770, Decrypted Result: 2134
#
#
# Node 692, Decrypted Result: 4115
# Node 4807, Decrypted Result: 142
# Node 4860, Decrypted Result: 64Node 4819, Decrypted Result: 85
#
# Node 4815, Decrypted Result: 9
# Node 4816, Decrypted Result: 21
# Node 4789, Decrypted Result: 18
# Node 725, Decrypted Result: 4179Node 717, Decrypted Result: 4232Node 4862, Decrypted Result: 62
#
#
# Node 720, Decrypted Result: 4104
# Node 2770, Decrypted Result: 2067
# Node 2777, Decrypted Result: 2127Node 2815, Decrypted Result: 2109Node 2766, Decrypted Result: 2183
#
#
# Node 4790, Decrypted Result: 17
# Node 4816, Decrypted Result: 8
# Node 2816, Decrypted Result: 2108Node 729, Decrypted Result: 4175Node 4815, Decrypted Result: 134Node 4819, Decrypted Result: 18
#
#
#
# Node 2770, Decrypted Result: 2054Node 4791, Decrypted Result: 16
#
# Node 2779, Decrypted Result: 2125Node 720, Decrypted Result: 4229Node 2817, Decrypted Result: 2107
#
#
# Node 725, Decrypted Result: 4112
# Node 4819, Decrypted Result: 5
# Node 2740, Decrypted Result: 2067
# Node 4828, Decrypted Result: 76Node 2818, Decrypted Result: 2106Node 4816, Decrypted Result: 133
#
#
# Node 2777, Decrypted Result: 2060
# Node 725, Decrypted Result: 4099
# Node 732, Decrypted Result: 4172Node 4867, Decrypted Result: 57Node 2770, Decrypted Result: 2179
#
#
# Node 4794, Decrypted Result: 13
# Node 729, Decrypted Result: 4108
# Node 2777, Decrypted Result: 2047
# Node 4868, Decrypted Result: 56Node 4819, Decrypted Result: 130Node 735, Decrypted Result: 4169
#
#
# Node 702, Decrypted Result: 4105
# Node 729, Decrypted Result: 4095Node 2779, Decrypted Result: 2058
#
# Node 4832, Decrypted Result: 72Node 4871, Decrypted Result: 53
#
# Node 725, Decrypted Result: 4224
# Node 2779, Decrypted Result: 2045Node 4799, Decrypted Result: 8Node 4828, Decrypted Result: 9
#
#
# Node 2826, Decrypted Result: 2098Node 737, Decrypted Result: 4167Node 2777, Decrypted Result: 2172
#
#
# Node 732, Decrypted Result: 4105Node 4828, Decrypted Result: -4Node 4804, Decrypted Result: 3
#
#
#
# Number 4824 NOT found after 414 comparisons.
# Node 2785, Decrypted Result: 2119Node 780, Decrypted Result: 4144Node 729, Decrypted Result: 4220
#
#
# Node 4877, Decrypted Result: 47Node 2787, Decrypted Result: 2117Node 735, Decrypted Result: 4102Node 710, Decrypted Result: 4097
#
#
#
# Node 2779, Decrypted Result: 2170
# Node 4879, Decrypted Result: 45Node 4837, Decrypted Result: 67Node 4832, Decrypted Result: 5Node 4828, Decrypted Result: 121
#
#
#
# Node 4807, Decrypted Result: 0
#
# Number 4807 found at iteration 402.
# Node 743, Decrypted Result: 4161Node 737, Decrypted Result: 4100Node 732, Decrypted Result: 4217Node 783, Decrypted Result: 4141
#
#
#
# Node 745, Decrypted Result: 4159Node 2785, Decrypted Result: 2052Node 735, Decrypted Result: 4214Node 2833, Decrypted Result: 2091
#
#
#
# Node 786, Decrypted Result: 4138Node 2795, Decrypted Result: 2109Node 2787, Decrypted Result: 2050Node 4832, Decrypted Result: 117
#
#
#
# Node 787, Decrypted Result: 4137Node 4837, Decrypted Result: 0Node 737, Decrypted Result: 4212Node 4844, Decrypted Result: 60
#
#
#
#
# Number 4837 found at iteration 421.
# Node 4843, Decrypted Result: 61Node 2836, Decrypted Result: 2088Node 2785, Decrypted Result: 2164
#
#
# Node 788, Decrypted Result: 4136Node 751, Decrypted Result: 4153Node 2787, Decrypted Result: 2162
#
#
# Node 4851, Decrypted Result: 53Node 2837, Decrypted Result: 2087Node 4837, Decrypted Result: 112
#
#
# Node 2839, Decrypted Result: 2085Node 743, Decrypted Result: 4206Node 4853, Decrypted Result: 51
#
#
# Node 2806, Decrypted Result: 2098Node 2841, Decrypted Result: 2083Node 745, Decrypted Result: 4204
#
#
# Node 4890, Decrypted Result: 34Node 2807, Decrypted Result: 2097Node 2795, Decrypted Result: 2154
#
#
# Node 2808, Decrypted Result: 2096Node 4844, Decrypted Result: 105
#
# Node 796, Decrypted Result: 4128
# Node 4854, Decrypted Result: 50Node 4843, Decrypted Result: 106
#
# Node 4893, Decrypted Result: 31
# Node 4860, Decrypted Result: 44Node 751, Decrypted Result: 4198
#
# Node 797, Decrypted Result: 4127
# Node 4862, Decrypted Result: 42Node 4851, Decrypted Result: 98
#
# Node 802, Decrypted Result: 4122
# Node 2815, Decrypted Result: 2089Node 4853, Decrypted Result: 96
#
# Node 803, Decrypted Result: 4121
# Node 2816, Decrypted Result: 2088Node 2806, Decrypted Result: 2143
#
# Node 2852, Decrypted Result: 2072
# Node 2817, Decrypted Result: 2087
# Node 2807, Decrypted Result: 2142
# Node 2808, Decrypted Result: 2141Node 4901, Decrypted Result: 23Node 2818, Decrypted Result: 2086
#
#
# Node 4867, Decrypted Result: 37Node 809, Decrypted Result: 4115Node 4854, Decrypted Result: 95
#
#
# Node 4868, Decrypted Result: 36
# Node 4860, Decrypted Result: 89
# Node 2858, Decrypted Result: 2066
# Node 4871, Decrypted Result: 33
# Node 811, Decrypted Result: 4113
# Node 4862, Decrypted Result: 87
# Node 2826, Decrypted Result: 2078
# Node 2815, Decrypted Result: 2134
# Node 780, Decrypted Result: 4124Node 4908, Decrypted Result: 16
#
# Node 4877, Decrypted Result: 27Node 2816, Decrypted Result: 2133
#
# Node 814, Decrypted Result: 4110
# Node 4879, Decrypted Result: 25Node 2817, Decrypted Result: 2132
#
# Node 816, Decrypted Result: 4108
# Node 783, Decrypted Result: 4121Node 2818, Decrypted Result: 2131
#
# Node 819, Decrypted Result: 4105
# Node 2833, Decrypted Result: 2071Node 4867, Decrypted Result: 82
#
# Node 4919, Decrypted Result: 5
# Node 786, Decrypted Result: 4118Node 4868, Decrypted Result: 81
#
# Node 787, Decrypted Result: 4117Node 4871, Decrypted Result: 78
#
# Node 824, Decrypted Result: 4100
# Node 2836, Decrypted Result: 2068Node 2826, Decrypted Result: 2123
#
# Node 826, Decrypted Result: 4098
# Node 788, Decrypted Result: 4116Node 780, Decrypted Result: 4169
#
# Node 4923, Decrypted Result: 1
# Node 2837, Decrypted Result: 2067
# Node 4877, Decrypted Result: 72
# Node 2839, Decrypted Result: 2065
# Node 4879, Decrypted Result: 70
# Node 4924, Decrypted Result: 0
#
# Number 4924 found at iteration 475.
# Node 2841, Decrypted Result: 2063
# Node 783, Decrypted Result: 4166
# Node 4890, Decrypted Result: 14
# Node 2833, Decrypted Result: 2116
# Node 796, Decrypted Result: 4108
# Node 786, Decrypted Result: 4163
# Node 4893, Decrypted Result: 11
# Node 787, Decrypted Result: 4162
# Node 797, Decrypted Result: 4107
# Node 2836, Decrypted Result: 2113
# Node 802, Decrypted Result: 4102
# Node 788, Decrypted Result: 4161
# Node 803, Decrypted Result: 4101
# Node 2837, Decrypted Result: 2112
# Node 2852, Decrypted Result: 2052
# Node 2839, Decrypted Result: 2110
# Node 4901, Decrypted Result: 3
# Node 809, Decrypted Result: 4095Node 2841, Decrypted Result: 2108
#
# Node 2858, Decrypted Result: 2046Node 4890, Decrypted Result: 59
#
# Node 811, Decrypted Result: 4093Node 796, Decrypted Result: 4153
#
# Node 4908, Decrypted Result: -4Node 4893, Decrypted Result: 56
#
#
# Number 4904 NOT found after 467 comparisons.
# Node 797, Decrypted Result: 4152
# Node 802, Decrypted Result: 4147
# Node 803, Decrypted Result: 4146
# Node 2852, Decrypted Result: 2097
# Node 4901, Decrypted Result: 48
# Node 809, Decrypted Result: 4140
# Node 2858, Decrypted Result: 2091
# Node 811, Decrypted Result: 4138
# Node 4908, Decrypted Result: 41
# Node 814, Decrypted Result: 4135
# Node 816, Decrypted Result: 4133
# Node 819, Decrypted Result: 4130
# Node 4919, Decrypted Result: 30
# Node 824, Decrypted Result: 4125
# Node 826, Decrypted Result: 4123
# Node 4923, Decrypted Result: 26
# Node 4924, Decrypted Result: 25
# Node 2880, Decrypted Result: 2069
# Node 2882, Decrypted Result: 2067
# Node 2883, Decrypted Result: 2066
# Node 838, Decrypted Result: 4111
# Node 2887, Decrypted Result: 2062
# Node 4935, Decrypted Result: 14
# Node 4934, Decrypted Result: 15
# Node 841, Decrypted Result: 4108
# Node 2891, Decrypted Result: 2058
# Node 4940, Decrypted Result: 9
# Node 845, Decrypted Result: 4104
# Node 2894, Decrypted Result: 2055
# Node 4946, Decrypted Result: 3
# Node 4949, Decrypted Result: 0
#
# Number 4949 found at iteration 489.
#
# Search Results:
# Number: 1266, Found: False, Comparisons: 1
# Number: 1338, Found: False, Comparisons: 1
# Number: 1424, Found: False, Comparisons: 1
# Number: 3967, Found: False, Comparisons: 1
# Number: 612, Found: False, Comparisons: 1
# Number: 658, Found: False, Comparisons: 1
# Number: 2442, Found: False, Comparisons: 1
# Number: 2236, Found: False, Comparisons: 1
# Number: 535, Found: False, Comparisons: 1
# Number: 3432, Found: False, Comparisons: 1
# Number: 2143, Found: False, Comparisons: 1
# Number: 2894, Found: False, Comparisons: 1
# Number: 680, Found: False, Comparisons: 1
# Number: 2097, Found: False, Comparisons: 1
# Number: 1891, Found: False, Comparisons: 1
# Number: 1956, Found: False, Comparisons: 1
# Number: 228, Found: False, Comparisons: 1
# Number: 856, Found: False, Comparisons: 1
# Number: 997, Found: False, Comparisons: 1
# Number: 716, Found: False, Comparisons: 1
# Number: 771, Found: False, Comparisons: 1
# Number: 999, Found: False, Comparisons: 1
# Number: 1722, Found: False, Comparisons: 1
# Number: 3696, Found: False, Comparisons: 1
# Number: 918, Found: False, Comparisons: 1
# Number: 2847, Found: False, Comparisons: 1
# Number: 2967, Found: False, Comparisons: 1
# Number: 1272, Found: False, Comparisons: 1
# Number: 1163, Found: False, Comparisons: 1
# Number: 589, Found: False, Comparisons: 1
# Number: 1630, Found: False, Comparisons: 1
# Number: 1191, Found: False, Comparisons: 1
# Number: 489, Found: False, Comparisons: 1
